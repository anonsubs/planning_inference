# %%
from meta_planning.parsers import parse_model, parse_problem, parse_plan
from meta_planning.generator import generate_trajectory
from meta_planning.observations import State, Trajectory
from meta_planning.pddl import Type, TypedObject, Effect, Truth, NumericConstant, PrimitiveNumericExpression, Increase
import copy
import glob
import os

# %%
### Blocks
# domain = "blocks"
# changes = {"object":{"subtypes": ["nblock", "oblock"], 
#                    "costs": [2,1],
#                    "actions": ["pick-up", "put-down", "stack", "unstack"]}}

## Driverlog
# domain = "driverlog"
# changes = {"truck":{"subtypes": ["ntruck", "otruck"],
#                    "costs": [1,5],
#                    "actions": ["load-truck", "unload-truck","board-truck", "disembark-truck", "drive-truck"]}}

### Ferry
# domain = "ferry"
# changes = {"location":{"subtypes": ["nlocation", "olocation"], 
#                    "costs": [2,1],
#                    "actions": ["sail", "board", "debark"]}}

### Goldminer
domain = "goldminer"
changes = {"loc":{"subtypes": ["nlocation", "olocation"], 
                   "costs": [5,1],
                   "actions": ["move"]}}

### Rover
# domain = "rovers"
# changes = {"rover":{"subtypes": ["nrover", "orover"], 
#                    "costs": [2,1],
#                    "actions": ["navigate", "sample-soil", "sample-rock", "take-image"]}}

### Parking
# domain = "parking"
# changes = {"rover":{"subtypes": ["nrover", "orover"], 
#                    "costs": [2,1],
#                    "actions": ["navigate", "sample-soil", "sample-rock", "take-image"]}}

### Intrusion
# domain = "intrusion"
# changes = {"host":{"subtypes": ["host"], 
#                    "costs": [1],
#                    "actions": ["navigate", "sample-soil", "sample-rock", "take-image"]}}

### Office
# domain = "office"
# changes = {"room":{"subtypes": ["nroom", "oroom"], 
#                    "costs": [3,1],
#                    "actions": ["move"]}}

# %%
M = parse_model("benchmarks/%s/domain.pddl" % domain)

new_M = copy.deepcopy(M)
new_M2 = copy.deepcopy(M)

for type_name in changes.keys():
    # Types
    new_types = []
    for subtype in changes[type_name]["subtypes"]:
        new_type = Type(subtype,basetype_name=type_name)
        new_types.append(new_type)
    
    # Schemata
    new_schemata = []
    for scheme in M.schemata:
        if scheme.name in changes[type_name]["actions"]:
            for i in range(len(changes[type_name]["subtypes"])):
                subtype = changes[type_name]["subtypes"][i]
                cost = changes[type_name]["costs"][i]
                
                new_scheme = copy.deepcopy(scheme)
                new_scheme.name = new_scheme.name + "-%s" % (subtype)
                
                new_parameters = []
                found = False
                for param in scheme.parameters:
                    if not found and param.type_name == type_name:
                        new_parameters.append(TypedObject(param.name, subtype))
                        found = True
                    else:
                        new_parameters.append(TypedObject(param.name, param.type_name))
                        
                new_scheme.parameters = new_parameters
                new_scheme.effects.append(Effect([], Truth(),
                       Increase(PrimitiveNumericExpression("total-cost", []), NumericConstant(cost))))
                
                new_schemata.append(new_scheme)
                        
        else:
            new_scheme = copy.deepcopy(scheme)
            new_scheme.effects.append(Effect([], Truth(),
                       Increase(PrimitiveNumericExpression("total-cost", []), NumericConstant(1))))
            new_schemata.append(new_scheme)
            
new_M.types += new_types
new_M.schemata = new_schemata
new_M.use_cost = True

new_M2.types = new_types

print(new_M)

new_M.to_file("domain.pddl")
new_M2.to_file("benchmarks/%s/trajectories/domain.pddl" % domain)
# Out:
# (define (domain robot)
# (:requirements :strips)
# (:types object room - object roomdoor - object package - object nroom - room oroom - room)
# (:predicates
# 	(armempty )
# 	(rloc ?loc - room)
# 	(in ?obj - package ?loc - room)
# 	(holding ?obj - package)
# 	(closed ?d - roomdoor)
# 	(door ?loc1 - room ?loc2 - room ?d - roomdoor)
# )
#
# (:functions (total-cost))
#
# (:action pickup
# 	:parameters (?obj - package ?loc - room)
# 	:precondition (and (rloc ?loc) (in ?obj ?loc) (armempty ))
# 	:effect (and
# 		(not (in ?obj ?loc))
# 		(not (armempty ))
# 		(holding ?obj)
# 		(increase (total-cost) 1)
# 	)
# )
#
# (:action putdown
# 	:parameters (?obj - package ?loc - room)
# 	:precondition (and (rloc ?loc) (holding ?obj))
# 	:effect (and
# 		(not (holding ?obj))
# 		(armempty )
# 		(in ?obj ?loc)
# 		(increase (total-cost) 1)
# 	)
# )
#
# (:action move-nroom
# 	:parameters (?loc1 - nroom ?loc2 - room ?d - roomdoor)
# 	:precondition (and (rloc ?loc1) (door ?loc1 ?loc2 ?d) (not (closed ?d)))
# 	:effect (and
# 		(rloc ?loc2)
# 		(not (rloc ?loc1))
# 		(increase (total-cost) 3)
# 	)
# )
#
# (:action move-oroom
# 	:parameters (?loc1 - oroom ?loc2 - room ?d - roomdoor)
# 	:precondition (and (rloc ?loc1) (door ?loc1 ?loc2 ?d) (not (closed ?d)))
# 	:effect (and
# 		(rloc ?loc2)
# 		(not (rloc ?loc1))
# 		(increase (total-cost) 1)
# 	)
# )
#
# (:action open
# 	:parameters (?loc1 - room ?loc2 - room ?d - roomdoor)
# 	:precondition (and (rloc ?loc1) (door ?loc1 ?loc2 ?d) (closed ?d))
# 	:effect (and
# 		(not (closed ?d))
# 		(increase (total-cost) 1)
# 	)
# ))

# %%
problems = glob.glob("benchmarks/%s/problems/*" % domain)

planner_path = "/home/dieaigar/PhD/downward/fast-downward.py"
cmd_args = [planner_path, '--plan-file solution_plan', "domain.pddl", "problem.pddl", '--evaluator "hff=ff()" --evaluator "hcea=cea()"', '--search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"']
cmd = " ".join(cmd_args)

num_t = 0

for i in range(len(problems)):
    
    P = parse_problem(problems[i], M)

    new_P = copy.deepcopy(P)

    new_objects = [o for o in P.objects if o.type_name not in changes.keys()]
    for type_name in changes.keys():  
        objects_of_type = [o for o in P.objects if o.type_name == type_name]
        count = 0
        num_subtypes = len(changes[type_name]["subtypes"])
        for o in objects_of_type:
            subtype = changes[type_name]["subtypes"][count%num_subtypes]
            new_objects.append(TypedObject(o.name, subtype))
            count += 1

    new_P.objects = new_objects
    new_P.use_metric = True

    print(new_P)

    new_P.to_file("problem.pddl")
    
    print(cmd)
    os.system(cmd)
    
    plan = parse_plan("solution_plan")
    
    print(plan)

    t = generate_trajectory(new_M, new_P, plan)
    
    
    # Remove type from action name
    subtypes = []
    for type_name in changes.keys():
        subtypes += changes[type_name]["subtypes"]
        
    for s in t.states[:-1]:
        action_name = s.next_action.name.split("-")
        if action_name[-1] in subtypes:
            action_name = "-".join(action_name[:-1])
            s.next_action.name = action_name
             
    
    
    for j in range(len(t.states)-10):
        states = t.states[j:j+10] + [State(t.states[j+10].literals, None)]
    
        new_t = Trajectory(t.objects, states)
    
        new_t.to_file("benchmarks/%s/trajectories/trajectory-%s" % (domain, str(num_t).zfill(3)))
        
        num_t += 1
# Out:
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d16 - roomdoor d610 - roomdoor d510 - roomdoor d06 - roomdoor d14 - roomdoor d910 - roomdoor d29 - roomdoor d28 - roomdoor d07 - roomdoor d13 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d07) (closed d16) (closed d28) (door c r6 d06) (door c r7 d07) (door r1 r3 d13) (door r1 r4 d14) (door r1 r6 d16) (door r10 r5 d510) (door r10 r6 d610) (door r10 r9 d910) (door r2 r8 d28) (door r2 r9 d29) (door r3 r1 d13) (door r4 r1 d14) (door r5 r10 d510) (door r6 c d06) (door r6 r1 d16) (door r6 r10 d610) (door r7 c d07) (door r8 r2 d28) (door r9 r10 d910) (door r9 r2 d29) (in o1 r5) (in o10 r1) (in o2 r8) (in o3 r8) (in o4 r1) (in o5 r10) (in o6 r5) (in o7 r1) (in o8 r6) (in o9 r5) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r9) (in o2 r6) (in o3 r6) (in o4 r2) (in o5 r7) (in o6 r2) (in o7 r3) (in o8 r3) (in o9 r5) (in o10 r1)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r7 d07)
# 1 : (move-nroom c r6 d06)
# 2 : (open r6 r1 d16)
# 3 : (move-nroom r6 r10 d610)
# 4 : (move-nroom r10 r9 d910)
# 5 : (move-oroom r9 r2 d29)
# 6 : (open r2 r8 d28)
# 7 : (move-nroom r2 r9 d29)
# 8 : (move-oroom r9 r10 d910)
# 9 : (move-nroom r10 r5 d510)
# 10 : (pickup o1 r5)
# 11 : (move-oroom r5 r10 d510)
# 12 : (move-nroom r10 r9 d910)
# 13 : (putdown o1 r9)
# 14 : (move-oroom r9 r10 d910)
# 15 : (move-nroom r10 r5 d510)
# 16 : (pickup o6 r5)
# 17 : (move-oroom r5 r10 d510)
# 18 : (move-nroom r10 r9 d910)
# 19 : (move-oroom r9 r2 d29)
# 20 : (putdown o6 r2)
# 21 : (move-nroom r2 r9 d29)
# 22 : (move-oroom r9 r10 d910)
# 23 : (move-nroom r10 r6 d610)
# 24 : (move-nroom r6 r1 d16)
# 25 : (pickup o7 r1)
# 26 : (move-oroom r1 r3 d13)
# 27 : (putdown o7 r3)
# 28 : (move-oroom r3 r1 d13)
# 29 : (pickup o4 r1)
# 30 : (move-oroom r1 r6 d16)
# 31 : (move-nroom r6 r10 d610)
# 32 : (move-nroom r10 r9 d910)
# 33 : (move-oroom r9 r2 d29)
# 34 : (putdown o4 r2)
# 35 : (move-nroom r2 r8 d28)
# 36 : (pickup o2 r8)
# 37 : (move-nroom r8 r2 d28)
# 38 : (move-nroom r2 r9 d29)
# 39 : (move-oroom r9 r10 d910)
# 40 : (move-nroom r10 r6 d610)
# 41 : (putdown o2 r6)
# 42 : (move-nroom r6 r10 d610)
# 43 : (pickup o5 r10)
# 44 : (move-nroom r10 r6 d610)
# 45 : (putdown o5 r6)
# 46 : (pickup o8 r6)
# 47 : (move-nroom r6 r1 d16)
# 48 : (move-oroom r1 r3 d13)
# 49 : (putdown o8 r3)
# 50 : (move-oroom r3 r1 d13)
# 51 : (move-oroom r1 r6 d16)
# 52 : (pickup o5 r6)
# 53 : (move-nroom r6 c d06)
# 54 : (move-nroom c r7 d07)
# 55 : (putdown o5 r7)
# 56 : (move-oroom r7 c d07)
# 57 : (move-nroom c r6 d06)
# 58 : (move-nroom r6 r10 d610)
# 59 : (move-nroom r10 r9 d910)
# 60 : (move-oroom r9 r2 d29)
# 61 : (move-nroom r2 r8 d28)
# 62 : (pickup o3 r8)
# 63 : (move-nroom r8 r2 d28)
# 64 : (move-nroom r2 r9 d29)
# 65 : (move-oroom r9 r10 d910)
# 66 : (move-nroom r10 r6 d610)
# 67 : (putdown o3 r6)
#
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d25 - roomdoor d58 - roomdoor d26 - roomdoor d46 - roomdoor d16 - roomdoor d89 - roomdoor d79 - roomdoor d05 - roomdoor d03 - roomdoor d310 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d03) (closed d05) (closed d16) (closed d310) (closed d46) (closed d58) (closed d79) (door c r3 d03) (door c r5 d05) (door r1 r6 d16) (door r10 r3 d310) (door r2 r5 d25) (door r2 r6 d26) (door r3 c d03) (door r3 r10 d310) (door r4 r6 d46) (door r5 c d05) (door r5 r2 d25) (door r5 r8 d58) (door r6 r1 d16) (door r6 r2 d26) (door r6 r4 d46) (door r7 r9 d79) (door r8 r5 d58) (door r8 r9 d89) (door r9 r7 d79) (door r9 r8 d89) (in o1 r9) (in o10 r1) (in o2 r4) (in o3 r1) (in o4 r6) (in o5 r9) (in o6 r7) (in o7 r2) (in o8 r4) (in o9 r9) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r4) (in o2 r2) (in o3 r10) (in o4 r1) (in o5 r9) (in o6 r7) (in o7 r3) (in o8 r2) (in o9 r8) (in o10 r9)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r3 d03)
# 1 : (open c r5 d05)
# 2 : (move-nroom c r5 d05)
# 3 : (open r5 r8 d58)
# 4 : (move-oroom r5 r2 d25)
# 5 : (move-nroom r2 r6 d26)
# 6 : (open r6 r1 d16)
# 7 : (open r6 r4 d46)
# 8 : (pickup o4 r6)
# 9 : (move-nroom r6 r1 d16)
# 10 : (putdown o4 r1)
# 11 : (pickup o10 r1)
# 12 : (move-oroom r1 r6 d16)
# 13 : (putdown o10 r6)
# 14 : (move-nroom r6 r1 d16)
# 15 : (pickup o3 r1)
# 16 : (move-oroom r1 r6 d16)
# 17 : (move-nroom r6 r2 d26)
# 18 : (move-nroom r2 r5 d25)
# 19 : (move-oroom r5 c d05)
# 20 : (move-nroom c r3 d03)
# 21 : (open r3 r10 d310)
# 22 : (move-oroom r3 r10 d310)
# 23 : (putdown o3 r10)
# 24 : (move-nroom r10 r3 d310)
# 25 : (move-oroom r3 c d03)
# 26 : (move-nroom c r5 d05)
# 27 : (move-oroom r5 r8 d58)
# 28 : (move-nroom r8 r9 d89)
# 29 : (pickup o9 r9)
# 30 : (move-oroom r9 r8 d89)
# 31 : (putdown o9 r8)
# 32 : (move-nroom r8 r9 d89)
# 33 : (pickup o1 r9)
# 34 : (move-oroom r9 r8 d89)
# 35 : (move-nroom r8 r5 d58)
# 36 : (move-oroom r5 r2 d25)
# 37 : (move-nroom r2 r6 d26)
# 38 : (move-nroom r6 r4 d46)
# 39 : (putdown o1 r4)
# 40 : (pickup o2 r4)
# 41 : (move-nroom r4 r6 d46)
# 42 : (move-nroom r6 r2 d26)
# 43 : (putdown o2 r2)
# 44 : (move-nroom r2 r6 d26)
# 45 : (pickup o10 r6)
# 46 : (move-nroom r6 r2 d26)
# 47 : (move-nroom r2 r5 d25)
# 48 : (putdown o10 r5)
# 49 : (move-oroom r5 r2 d25)
# 50 : (pickup o7 r2)
# 51 : (move-nroom r2 r5 d25)
# 52 : (move-oroom r5 c d05)
# 53 : (move-nroom c r3 d03)
# 54 : (putdown o7 r3)
# 55 : (move-oroom r3 c d03)
# 56 : (move-nroom c r5 d05)
# 57 : (pickup o10 r5)
# 58 : (move-oroom r5 r8 d58)
# 59 : (move-nroom r8 r9 d89)
# 60 : (putdown o10 r9)
# 61 : (move-oroom r9 r8 d89)
# 62 : (move-nroom r8 r5 d58)
# 63 : (move-oroom r5 r2 d25)
# 64 : (move-nroom r2 r6 d26)
# 65 : (move-nroom r6 r4 d46)
# 66 : (pickup o8 r4)
# 67 : (move-nroom r4 r6 d46)
# 68 : (move-nroom r6 r2 d26)
# 69 : (putdown o8 r2)
#
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d16 - roomdoor d610 - roomdoor d510 - roomdoor d06 - roomdoor d14 - roomdoor d910 - roomdoor d29 - roomdoor d28 - roomdoor d07 - roomdoor d13 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d07) (closed d16) (closed d28) (door c r6 d06) (door c r7 d07) (door r1 r3 d13) (door r1 r4 d14) (door r1 r6 d16) (door r10 r5 d510) (door r10 r6 d610) (door r10 r9 d910) (door r2 r8 d28) (door r2 r9 d29) (door r3 r1 d13) (door r4 r1 d14) (door r5 r10 d510) (door r6 c d06) (door r6 r1 d16) (door r6 r10 d610) (door r7 c d07) (door r8 r2 d28) (door r9 r10 d910) (door r9 r2 d29) (in o1 r5) (in o10 r1) (in o2 r8) (in o3 r5) (in o4 r1) (in o5 r10) (in o6 r5) (in o7 r1) (in o8 r6) (in o9 r5) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r9) (in o2 r6) (in o3 r6) (in o4 r7) (in o5 r2) (in o6 r2) (in o7 r7) (in o8 r7) (in o9 r5) (in o10 r1)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r7 d07)
# 1 : (move-nroom c r6 d06)
# 2 : (open r6 r1 d16)
# 3 : (move-nroom r6 r10 d610)
# 4 : (move-nroom r10 r5 d510)
# 5 : (pickup o1 r5)
# 6 : (move-oroom r5 r10 d510)
# 7 : (move-nroom r10 r9 d910)
# 8 : (putdown o1 r9)
# 9 : (move-oroom r9 r10 d910)
# 10 : (move-nroom r10 r5 d510)
# 11 : (pickup o3 r5)
# 12 : (move-oroom r5 r10 d510)
# 13 : (move-nroom r10 r9 d910)
# 14 : (putdown o3 r9)
# 15 : (move-oroom r9 r10 d910)
# 16 : (move-nroom r10 r5 d510)
# 17 : (pickup o6 r5)
# 18 : (move-oroom r5 r10 d510)
# 19 : (move-nroom r10 r9 d910)
# 20 : (move-oroom r9 r2 d29)
# 21 : (open r2 r8 d28)
# 22 : (putdown o6 r2)
# 23 : (move-nroom r2 r9 d29)
# 24 : (pickup o3 r9)
# 25 : (move-oroom r9 r10 d910)
# 26 : (move-nroom r10 r6 d610)
# 27 : (putdown o3 r6)
# 28 : (move-nroom r6 r1 d16)
# 29 : (pickup o4 r1)
# 30 : (move-oroom r1 r6 d16)
# 31 : (putdown o4 r6)
# 32 : (move-nroom r6 r1 d16)
# 33 : (pickup o7 r1)
# 34 : (move-oroom r1 r6 d16)
# 35 : (move-nroom r6 c d06)
# 36 : (move-nroom c r7 d07)
# 37 : (putdown o7 r7)
# 38 : (move-oroom r7 c d07)
# 39 : (move-nroom c r6 d06)
# 40 : (move-nroom r6 r10 d610)
# 41 : (pickup o5 r10)
# 42 : (move-nroom r10 r9 d910)
# 43 : (move-oroom r9 r2 d29)
# 44 : (putdown o5 r2)
# 45 : (move-nroom r2 r8 d28)
# 46 : (pickup o2 r8)
# 47 : (move-nroom r8 r2 d28)
# 48 : (move-nroom r2 r9 d29)
# 49 : (move-oroom r9 r10 d910)
# 50 : (move-nroom r10 r6 d610)
# 51 : (putdown o2 r6)
# 52 : (pickup o4 r6)
# 53 : (move-nroom r6 c d06)
# 54 : (move-nroom c r7 d07)
# 55 : (putdown o4 r7)
# 56 : (move-oroom r7 c d07)
# 57 : (move-nroom c r6 d06)
# 58 : (pickup o8 r6)
# 59 : (move-nroom r6 c d06)
# 60 : (move-nroom c r7 d07)
# 61 : (putdown o8 r7)
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d16 - roomdoor d610 - roomdoor d510 - roomdoor d06 - roomdoor d14 - roomdoor d910 - roomdoor d29 - roomdoor d28 - roomdoor d07 - roomdoor d13 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d07) (closed d16) (closed d28) (door c r6 d06) (door c r7 d07) (door r1 r3 d13) (door r1 r4 d14) (door r1 r6 d16) (door r10 r5 d510) (door r10 r6 d610) (door r10 r9 d910) (door r2 r8 d28) (door r2 r9 d29) (door r3 r1 d13) (door r4 r1 d14) (door r5 r10 d510) (door r6 c d06) (door r6 r1 d16) (door r6 r10 d610) (door r7 c d07) (door r8 r2 d28) (door r9 r10 d910) (door r9 r2 d29) (in o1 r2) (in o10 r1) (in o2 r2) (in o3 r3) (in o4 r6) (in o5 r9) (in o6 r10) (in o7 r8) (in o8 r5) (in o9 r5) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r1) (in o2 r8) (in o3 r2) (in o4 r6) (in o5 r4) (in o6 r5) (in o7 r10) (in o8 r7) (in o9 r9) (in o10 r3)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r7 d07)
# 1 : (move-nroom c r6 d06)
# 2 : (open r6 r1 d16)
# 3 : (move-nroom r6 r1 d16)
# 4 : (pickup o10 r1)
# 5 : (move-oroom r1 r3 d13)
# 6 : (putdown o10 r3)
# 7 : (pickup o3 r3)
# 8 : (move-oroom r3 r1 d13)
# 9 : (move-oroom r1 r6 d16)
# 10 : (move-nroom r6 r10 d610)
# 11 : (move-nroom r10 r5 d510)
# 12 : (putdown o3 r5)
# 13 : (move-oroom r5 r10 d510)
# 14 : (move-nroom r10 r9 d910)
# 15 : (move-oroom r9 r2 d29)
# 16 : (open r2 r8 d28)
# 17 : (move-nroom r2 r9 d29)
# 18 : (pickup o5 r9)
# 19 : (move-oroom r9 r10 d910)
# 20 : (putdown o5 r10)
# 21 : (move-nroom r10 r5 d510)
# 22 : (pickup o3 r5)
# 23 : (move-oroom r5 r10 d510)
# 24 : (move-nroom r10 r9 d910)
# 25 : (move-oroom r9 r2 d29)
# 26 : (putdown o3 r2)
# 27 : (move-nroom r2 r9 d29)
# 28 : (move-oroom r9 r10 d910)
# 29 : (move-nroom r10 r5 d510)
# 30 : (pickup o8 r5)
# 31 : (move-oroom r5 r10 d510)
# 32 : (putdown o8 r10)
# 33 : (move-nroom r10 r5 d510)
# 34 : (pickup o9 r5)
# 35 : (move-oroom r5 r10 d510)
# 36 : (move-nroom r10 r9 d910)
# 37 : (putdown o9 r9)
# 38 : (move-oroom r9 r10 d910)
# 39 : (pickup o6 r10)
# 40 : (move-nroom r10 r5 d510)
# 41 : (putdown o6 r5)
# 42 : (move-oroom r5 r10 d510)
# 43 : (move-nroom r10 r9 d910)
# 44 : (move-oroom r9 r2 d29)
# 45 : (pickup o2 r2)
# 46 : (move-nroom r2 r8 d28)
# 47 : (putdown o2 r8)
# 48 : (pickup o7 r8)
# 49 : (move-nroom r8 r2 d28)
# 50 : (move-nroom r2 r9 d29)
# 51 : (move-oroom r9 r10 d910)
# 52 : (putdown o7 r10)
# 53 : (pickup o5 r10)
# 54 : (move-nroom r10 r6 d610)
# 55 : (move-nroom r6 r1 d16)
# 56 : (move-oroom r1 r4 d14)
# 57 : (putdown o5 r4)
# 58 : (move-nroom r4 r1 d14)
# 59 : (move-oroom r1 r6 d16)
# 60 : (move-nroom r6 r10 d610)
# 61 : (move-nroom r10 r9 d910)
# 62 : (move-oroom r9 r2 d29)
# 63 : (pickup o1 r2)
# 64 : (move-nroom r2 r9 d29)
# 65 : (move-oroom r9 r10 d910)
# 66 : (move-nroom r10 r6 d610)
# 67 : (move-nroom r6 r1 d16)
# 68 : (putdown o1 r1)
# 69 : (move-oroom r1 r6 d16)
# 70 : (move-nroom r6 r10 d610)
# 71 : (pickup o8 r10)
# 72 : (move-nroom r10 r6 d610)
# 73 : (move-nroom r6 c d06)
# 74 : (move-nroom c r7 d07)
# 75 : (putdown o8 r7)
#
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d25 - roomdoor d58 - roomdoor d26 - roomdoor d46 - roomdoor d16 - roomdoor d89 - roomdoor d79 - roomdoor d05 - roomdoor d03 - roomdoor d310 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d03) (closed d05) (closed d16) (closed d310) (closed d46) (closed d58) (closed d79) (door c r3 d03) (door c r5 d05) (door r1 r6 d16) (door r10 r3 d310) (door r2 r5 d25) (door r2 r6 d26) (door r3 c d03) (door r3 r10 d310) (door r4 r6 d46) (door r5 c d05) (door r5 r2 d25) (door r5 r8 d58) (door r6 r1 d16) (door r6 r2 d26) (door r6 r4 d46) (door r7 r9 d79) (door r8 r5 d58) (door r8 r9 d89) (door r9 r7 d79) (door r9 r8 d89) (in o1 r4) (in o10 r1) (in o2 r10) (in o3 r2) (in o4 r6) (in o5 r9) (in o6 r6) (in o7 r7) (in o8 r4) (in o9 r9) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r1) (in o2 r3) (in o3 r5) (in o4 r2) (in o5 r6) (in o6 r8) (in o7 r7) (in o8 r3) (in o9 r9) (in o10 r1)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r3 d03)
# 1 : (open c r5 d05)
# 2 : (move-nroom c r5 d05)
# 3 : (open r5 r8 d58)
# 4 : (move-oroom r5 r2 d25)
# 5 : (move-nroom r2 r6 d26)
# 6 : (open r6 r1 d16)
# 7 : (open r6 r4 d46)
# 8 : (move-nroom r6 r2 d26)
# 9 : (pickup o3 r2)
# 10 : (move-nroom r2 r5 d25)
# 11 : (putdown o3 r5)
# 12 : (move-oroom r5 c d05)
# 13 : (move-nroom c r3 d03)
# 14 : (open r3 r10 d310)
# 15 : (move-oroom r3 c d03)
# 16 : (move-nroom c r5 d05)
# 17 : (move-oroom r5 r8 d58)
# 18 : (move-nroom r8 r9 d89)
# 19 : (pickup o5 r9)
# 20 : (move-oroom r9 r8 d89)
# 21 : (move-nroom r8 r5 d58)
# 22 : (move-oroom r5 r2 d25)
# 23 : (move-nroom r2 r6 d26)
# 24 : (putdown o5 r6)
# 25 : (pickup o4 r6)
# 26 : (move-nroom r6 r2 d26)
# 27 : (putdown o4 r2)
# 28 : (move-nroom r2 r6 d26)
# 29 : (move-nroom r6 r4 d46)
# 30 : (pickup o1 r4)
# 31 : (move-nroom r4 r6 d46)
# 32 : (move-nroom r6 r1 d16)
# 33 : (putdown o1 r1)
# 34 : (move-oroom r1 r6 d16)
# 35 : (pickup o6 r6)
# 36 : (move-nroom r6 r2 d26)
# 37 : (move-nroom r2 r5 d25)
# 38 : (move-oroom r5 r8 d58)
# 39 : (putdown o6 r8)
# 40 : (move-nroom r8 r5 d58)
# 41 : (move-oroom r5 c d05)
# 42 : (move-nroom c r3 d03)
# 43 : (move-oroom r3 r10 d310)
# 44 : (pickup o2 r10)
# 45 : (move-nroom r10 r3 d310)
# 46 : (putdown o2 r3)
# 47 : (move-oroom r3 c d03)
# 48 : (move-nroom c r5 d05)
# 49 : (move-oroom r5 r2 d25)
# 50 : (move-nroom r2 r6 d26)
# 51 : (move-nroom r6 r4 d46)
# 52 : (pickup o8 r4)
# 53 : (move-nroom r4 r6 d46)
# 54 : (move-nroom r6 r2 d26)
# 55 : (move-nroom r2 r5 d25)
# 56 : (move-oroom r5 c d05)
# 57 : (move-nroom c r3 d03)
# 58 : (putdown o8 r3)
#
# (define (problem pfile_10_10)
# 	(:domain robot)
# 	(:objects o1 - package o2 - package o3 - package o4 - package o5 - package o6 - package o7 - package o8 - package o9 - package o10 - package d25 - roomdoor d58 - roomdoor d26 - roomdoor d46 - roomdoor d16 - roomdoor d89 - roomdoor d79 - roomdoor d05 - roomdoor d03 - roomdoor d310 - roomdoor c - nroom r1 - oroom r2 - nroom r3 - oroom r4 - nroom r5 - oroom r6 - nroom r7 - oroom r8 - nroom r9 - oroom r10 - nroom)
# 	(:init
# 	(armempty ) (closed d03) (closed d05) (closed d16) (closed d310) (closed d46) (closed d58) (closed d79) (door c r3 d03) (door c r5 d05) (door r1 r6 d16) (door r10 r3 d310) (door r2 r5 d25) (door r2 r6 d26) (door r3 c d03) (door r3 r10 d310) (door r4 r6 d46) (door r5 c d05) (door r5 r2 d25) (door r5 r8 d58) (door r6 r1 d16) (door r6 r2 d26) (door r6 r4 d46) (door r7 r9 d79) (door r8 r5 d58) (door r8 r9 d89) (door r9 r7 d79) (door r9 r8 d89) (in o1 r1) (in o10 r1) (in o2 r2) (in o3 r1) (in o4 r6) (in o5 r9) (in o6 r1) (in o7 r7) (in o8 r4) (in o9 r9) (rloc c)
# (= (total-cost) 0)
# 	)
# 	(:goal (and (in o1 r5) (in o2 r3) (in o3 r1) (in o4 r2) (in o5 r1) (in o6 r8) (in o7 r4) (in o8 r3) (in o9 r9) (in o10 r1)))
# (:metric minimize (total-cost))
# )
# /home/dieaigar/PhD/downward/fast-downward.py --plan-file solution_plan domain.pddl problem.pddl --evaluator "hff=ff()" --evaluator "hcea=cea()" --search "lazy_greedy([hff, hcea], preferred=[hff, hcea])"
# 0 : (open c r3 d03)
# 1 : (open c r5 d05)
# 2 : (move-nroom c r5 d05)
# 3 : (open r5 r8 d58)
# 4 : (move-oroom r5 r2 d25)
# 5 : (move-nroom r2 r6 d26)
# 6 : (open r6 r1 d16)
# 7 : (open r6 r4 d46)
# 8 : (move-nroom r6 r1 d16)
# 9 : (pickup o1 r1)
# 10 : (move-oroom r1 r6 d16)
# 11 : (move-nroom r6 r2 d26)
# 12 : (move-nroom r2 r5 d25)
# 13 : (putdown o1 r5)
# 14 : (move-oroom r5 r8 d58)
# 15 : (move-nroom r8 r9 d89)
# 16 : (open r9 r7 d79)
# 17 : (move-oroom r9 r8 d89)
# 18 : (move-nroom r8 r5 d58)
# 19 : (move-oroom r5 r2 d25)
# 20 : (move-nroom r2 r6 d26)
# 21 : (move-nroom r6 r1 d16)
# 22 : (pickup o6 r1)
# 23 : (move-oroom r1 r6 d16)
# 24 : (move-nroom r6 r2 d26)
# 25 : (move-nroom r2 r5 d25)
# 26 : (move-oroom r5 r8 d58)
# 27 : (putdown o6 r8)
# 28 : (move-nroom r8 r5 d58)
# 29 : (move-oroom r5 r2 d25)
# 30 : (pickup o2 r2)
# 31 : (move-nroom r2 r5 d25)
# 32 : (putdown o2 r5)
# 33 : (move-oroom r5 r8 d58)
# 34 : (move-nroom r8 r9 d89)
# 35 : (pickup o5 r9)
# 36 : (move-oroom r9 r8 d89)
# 37 : (move-nroom r8 r5 d58)
# 38 : (move-oroom r5 r2 d25)
# 39 : (move-nroom r2 r6 d26)
# 40 : (move-nroom r6 r1 d16)
# 41 : (putdown o5 r1)
# 42 : (move-oroom r1 r6 d16)
# 43 : (pickup o4 r6)
# 44 : (move-nroom r6 r2 d26)
# 45 : (putdown o4 r2)
# 46 : (move-nroom r2 r5 d25)
# 47 : (move-oroom r5 r8 d58)
# 48 : (move-nroom r8 r9 d89)
# 49 : (move-oroom r9 r7 d79)
# 50 : (pickup o7 r7)
# 51 : (move-oroom r7 r9 d79)
# 52 : (move-oroom r9 r8 d89)
# 53 : (move-nroom r8 r5 d58)
# 54 : (move-oroom r5 r2 d25)
# 55 : (move-nroom r2 r6 d26)
# 56 : (move-nroom r6 r4 d46)
# 57 : (putdown o7 r4)
# 58 : (pickup o8 r4)
# 59 : (move-nroom r4 r6 d46)
# 60 : (move-nroom r6 r2 d26)
# 61 : (move-nroom r2 r5 d25)
# 62 : (move-oroom r5 c d05)
# 63 : (move-nroom c r3 d03)
# 64 : (putdown o8 r3)
# 65 : (move-oroom r3 c d03)
# 66 : (move-nroom c r5 d05)
# 67 : (pickup o2 r5)
# 68 : (move-oroom r5 c d05)
# 69 : (move-nroom c r3 d03)
# 70 : (putdown o2 r3)

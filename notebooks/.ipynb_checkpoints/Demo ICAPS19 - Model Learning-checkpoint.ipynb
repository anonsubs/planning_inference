# %%
from meta_planning import dataset
from meta_planning import LearningTask
from meta_planning.evaluation import SynEvaluator

# %% [markdown]
# # Model Learning
#
# A model learning task is defined as $\Lambda = <m,\mathcal{O}>$, where
#
# * $m$ is the initial empty domain model
# * $\mathcal{O}$ is a set of observations
#
# A solution to $\Lambda$ consists of:
# * a model $m'$ consistent with $m$ and $\mathcal{O}$
# * a set of of explanations $\mathcal{E} = \{<t,o> | o \in \mathcal{O}\}$ where $t$ is a trajectory generated by $m'$ and consistent with $o$

# %% [markdown]
# ### Pick a domain

# %%
dataset.list_learning_domains()
# Out:
# Learning domains:
# 	 blocks
# 	 driverlog
# 	 ferry
# 	 floortile
# 	 grid
# 	 gripper
# 	 hanoi
# 	 miconic
# 	 npuzzle
# 	 parking
# 	 rovers
# 	 satellite
# 	 transport
# 	 visitall
# 	 zenotravel

# %%
domain = "blocks"

# %% [markdown]
# ### Define the initial model

# %%
m_ref = dataset.load_model(domain)

m = m_ref.observe(precondition_observability=0, effect_observability=0)

print(m)
# Out:
# (define (domain blocks)
# (:requirements :strips)
# (:types object)
# (:predicates
# 	(on ?o1 - object ?o2 - object)
# 	(ontable ?o1 - object)
# 	(clear ?o1 - object)
# 	(handempty )
# 	(holding ?o1 - object)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# ))

# %% [markdown]
# ### Define the observations
#
# An observation is a partially observed trajectory $\tau = <s_0, a_1, s_1, \ldots, a_n, s_n >$.
#
# **Setting 1 - Bounded solution:** The length of the observed trajectory is known when:
# * every action is observed, or
# * every state is observed (even partially).
#
# **Setting 2 - Unbounded solution:** The observation is not indicative of the length of the trajectory when:
# * there are missing actions, and
# * there are missing states.

# %%
num_observations = 2 #1-10
T = dataset.load_trajectories(domain, select=range(num_observations))

O = [t.observe(0.4, action_observability=0, goal_observability=1, keep_every_state=False) for t in T]

print(O[0])
# Out:
# (observation
#
# (:objects e - object b - object f - object d - object c - object g - object a - object)
#
# (:state (clear a) (not (clear b)) (clear c) (not (clear d)) (not (clear e)) (not (clear f)) (not (clear g)) (handempty ) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding d)) (not (holding e)) (not (holding f)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a d)) (not (on a e)) (not (on a f)) (on a g) (not (on b a)) (not (on b b)) (not (on b c)) (not (on b d)) (on b e) (not (on b f)) (not (on b g)) (not (on c a)) (not (on c b)) (not (on c c)) (on c d) (not (on c e)) (not (on c f)) (not (on c g)) (not (on d a)) (on d b) (not (on d c)) (not (on d d)) (not (on d e)) (not (on d f)) (not (on d g)) (not (on e a)) (not (on e b)) (not (on e c)) (not (on e d)) (not (on e e)) (on e f) (not (on e g)) (not (on f a)) (not (on f b)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on f f)) (not (on f g)) (not (on g a)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g e)) (not (on g f)) (not (on g g)) (not (ontable a)) (not (ontable b)) (not (ontable c)) (not (ontable d)) (not (ontable e)) (ontable f) (ontable g))
#
# (:state (clear a) (not (clear c)) (not (clear e)) (not (clear g)) (not (holding a)) (not (holding b)) (holding c) (not (holding d)) (not (holding e)) (not (holding g)) (not (on a b)) (not (on a c)) (not (on a f)) (on a g) (not (on b b)) (on b e) (not (on c a)) (not (on c c)) (not (on c g)) (not (on d a)) (not (on e c)) (not (on e d)) (on e f) (not (on f c)) (not (on f d)) (not (on f e)) (not (on f f)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g f)) (not (on g g)) (not (ontable a)))
#
# (:state (clear a) (clear c) (not (clear g)) (handempty ) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding d)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a e)) (on a g) (not (on b d)) (not (on b g)) (not (on c a)) (not (on d a)) (on d b) (not (on d c)) (not (on d e)) (not (on e a)) (not (on e e)) (on e f) (not (on f d)) (not (on f e)) (not (on f f)) (not (on g a)) (not (on g f)) (not (ontable a)) (not (ontable e)))
#
# (:state (clear b) (clear c) (not (clear e)) (not (clear f)) (not (clear g)) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding f)) (not (on a a)) (not (on a b)) (not (on a c)) (on b e) (not (on c b)) (not (on c c)) (not (on c e)) (not (on d e)) (not (on d f)) (not (on e a)) (not (on e d)) (on e f) (not (on f b)) (not (on f d)) (not (on g a)) (not (on g c)) (not (on g e)) (not (on g f)) (not (ontable a)) (ontable c) (not (ontable d)) (not (ontable e)))
#
# (:state (clear b) (not (clear e)) (not (holding a)) (not (holding c)) (not (holding d)) (not (on a a)) (not (on a c)) (not (on a f)) (on b e) (not (on c a)) (not (on c b)) (not (on c d)) (not (on c e)) (not (on c f)) (not (on d d)) (not (on d e)) (not (on e c)) (on e f) (not (on e g)) (not (on f c)) (not (on f d)) (not (on f f)) (not (on g c)) (not (on g g)) (not (ontable b)) (ontable c) (not (ontable d)) (not (ontable e)) (ontable g))
#
# (:state (not (clear a)) (clear d) (not (holding a)) (holding b) (not (holding c)) (not (holding f)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a d)) (not (on b a)) (not (on b d)) (not (on b e)) (not (on c a)) (not (on c e)) (not (on c g)) (on d a) (not (on d c)) (not (on d g)) (not (on e a)) (not (on e d)) (not (on e e)) (not (on f a)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on g b)) (not (on g c)) (not (on g e)) (not (on g g)) (not (ontable d)) (ontable g))
#
# (:state (not (clear a)) (clear e) (not (clear f)) (handempty ) (not (holding a)) (not (on a a)) (not (on a d)) (not (on b b)) (not (on b d)) (not (on b e)) (not (on c a)) (not (on c e)) (on d a) (not (on d c)) (not (on d d)) (not (on d e)) (not (on d g)) (not (on e c)) (not (on e d)) (not (on f c)) (not (on f d)) (not (on f g)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g e)) (ontable c) (ontable f))
#
# (:state (not (clear d)) (clear e) (not (clear f)) (not (clear g)) (holding d) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a e)) (on a g) (not (on b a)) (not (on b b)) (not (on b e)) (not (on b f)) (not (on c a)) (not (on c e)) (not (on c f)) (not (on d b)) (not (on d c)) (not (on d d)) (not (on d e)) (not (on e e)) (not (on f b)) (not (on f d)) (not (on g b)) (not (on g e)) (not (on g f)) (not (ontable a)) (ontable b) (not (ontable d)) (ontable f))
#
# (:state (clear d) (clear e) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding e)) (not (on a a)) (not (on a c)) (not (on a e)) (not (on b f)) (not (on d a)) (not (on d e)) (not (on e c)) (not (on e d)) (not (on e e)) (not (on f a)) (not (on f c)) (not (on f d)) (not (on f f)) (not (on g g)) (ontable c))
#
# (:state (clear b) (not (clear d)) (not (holding a)) (not (holding c)) (not (holding e)) (not (on a a)) (not (on a c)) (not (on a e)) (not (on b a)) (not (on b b)) (not (on b c)) (not (on b f)) (not (on c c)) (not (on d b)) (not (on d c)) (not (on d e)) (not (on f a)) (not (on f b)) (not (on g a)) (not (on g c)) (not (on g e)) (not (on g f)) (not (on g g)) (not (ontable a)) (ontable b) (not (ontable e)))
#
# (:state (clear a) (clear b) (clear c) (clear d) (clear e) (not (clear f)) (not (clear g)) (handempty ) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding d)) (not (holding e)) (not (holding f)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a d)) (not (on a e)) (not (on a f)) (on a g) (not (on b a)) (not (on b b)) (not (on b c)) (not (on b d)) (not (on b e)) (not (on b f)) (not (on b g)) (not (on c a)) (not (on c b)) (not (on c c)) (not (on c d)) (not (on c e)) (not (on c f)) (not (on c g)) (not (on d a)) (not (on d b)) (not (on d c)) (not (on d d)) (not (on d e)) (not (on d f)) (not (on d g)) (not (on e a)) (not (on e b)) (not (on e c)) (not (on e d)) (not (on e e)) (on e f) (not (on e g)) (not (on f a)) (not (on f b)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on f f)) (not (on f g)) (not (on g a)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g e)) (not (on g f)) (not (on g g)) (not (ontable a)) (ontable b) (ontable c) (ontable d) (not (ontable e)) (ontable f) (ontable g)))

# %% [markdown]
# ### Solve the task

# %%
task = LearningTask(m,O)

solution = task.learn()
# Out:
# ulimit -t 3000; /home/dieaigar/PhD/meta-planning/src/meta_planning/util/planners/madagascar/M compiled_domain compiled_problem -S 1 -Q -o solution_plan -F 41 > planner_out

# %%
print(solution.learned_model)
# Out:
# (define (domain blocks)
# (:requirements :strips)
# (:types object)
# (:predicates
# 	(on ?o1 - object ?o2 - object)
# 	(ontable ?o1 - object)
# 	(clear ?o1 - object)
# 	(handempty )
# 	(holding ?o1 - object)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and (holding ?o1))
# 	:effect (and
# 		(handempty )
# 		(clear ?o1)
# 		(ontable ?o1)
# 		(not (holding ?o1))
# 		0
# 	)
# )
#
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and (handempty ) (clear ?o1) (ontable ?o1))
# 	:effect (and
# 		(not (handempty ))
# 		(not (clear ?o1))
# 		(not (ontable ?o1))
# 		(holding ?o1)
# 		0
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and (handempty ) (clear ?o2) (on ?o2 ?o1))
# 	:effect (and
# 		(clear ?o1)
# 		(not (on ?o2 ?o1))
# 		(holding ?o2)
# 		(not (clear ?o2))
# 		0
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and (handempty ) (clear ?o1) (holding ?o2))
# 	:effect (and
# 		(not (clear ?o1))
# 		(on ?o2 ?o1)
# 		(not (holding ?o2))
# 		(clear ?o2)
# 		0
# 	)
# ))

# %%
print(solution.solution_plan)
# Out:
# 0 : (insert_eff_pick-up_clear_var1 )
# 1 : (insert_eff_pick-up_handempty )
# 2 : (insert_eff_pick-up_holding_var1 )
# 3 : (insert_eff_pick-up_ontable_var1 )
# 4 : (insert_eff_put-down_clear_var1 )
# 5 : (insert_eff_put-down_handempty )
# 6 : (insert_eff_put-down_holding_var1 )
# 7 : (insert_eff_put-down_ontable_var1 )
# 8 : (insert_eff_stack_clear_var1 )
# 9 : (insert_eff_stack_clear_var2 )
# 10 : (insert_eff_stack_holding_var2 )
# 11 : (insert_eff_stack_on_var2_var1 )
# 12 : (insert_eff_unstack_clear_var1 )
# 13 : (insert_eff_unstack_clear_var2 )
# 14 : (insert_eff_unstack_holding_var2 )
# 15 : (insert_eff_unstack_on_var2_var1 )
# 16 : (insert_pre_pick-up_holding_var1 )
# 17 : (insert_pre_put-down_clear_var1 )
# 18 : (insert_pre_put-down_handempty )
# 19 : (insert_pre_put-down_ontable_var1 )
# 20 : (insert_pre_stack_clear_var2 )
# 21 : (insert_pre_stack_handempty )
# 22 : (insert_pre_stack_on_var2_var1 )
# 23 : (insert_pre_unstack_clear_var1 )
# 24 : (insert_pre_unstack_handempty )
# 25 : (insert_pre_unstack_holding_var2 )
# 26 : (validate_0 )
# 27 : (stack d c)
# 28 : (validate_1 )
# 29 : (pick-up c)
# 30 : (validate_2 )
# 31 : (stack b d)
# 32 : (validate_3 )
# 33 : (unstack a d)
# 34 : (validate_4 )
# 35 : (stack e b)
# 36 : (validate_5 )
# 37 : (pick-up b)
# 38 : (validate_6 )
# 39 : (stack a d)
# 40 : (validate_7 )
# 41 : (pick-up d)
# 42 : (validate_8 )
# 43 : (put-down d)
# 44 : (validate_9 )
# 45 : (pick-up d)
# 46 : (validate_10 )
# 47 : (stack f e)
# 48 : (validate_11 )
# 49 : (pick-up e)
# 50 : (validate_12 )
# 51 : (stack g a)
# 52 : (validate_13 )
# 53 : (pick-up a)
# 54 : (validate_14 )
# 55 : (put-down a)
# 56 : (validate_15 )
# 57 : (pick-up a)
# 58 : (validate_16 )
# 59 : (put-down a)
# 60 : (validate_17 )
# 61 : (pick-up a)
# 62 : (validate_18 )
# 63 : (put-down b)
# 64 : (validate_19 )
# 65 : (pick-up b)
# 66 : (validate_20 )

# %% [markdown]
# ### Evaluate the learned model

# %% [markdown]
# ### Evaluate the learned model
#
# The evaluation metrics are:
#
# $Precision=\frac{tp}{tp+fp}=\frac{size(\mathcal{M})- \left|DEL(\mathcal{M},GTM)\right|}{size(\mathcal{M})}$
#
# $Recall= \frac{tp}{tp+fn}=\frac{size(\mathcal{M})- \left|DEL(\mathcal{M},GTM)\right|}{size(\mathcal{M}) - \left|DEL(\mathcal{M},GTM)\right| + \left|INS(\mathcal{M},GTM)\right|}$

# %%
evaluator = SynEvaluator(solution.learned_model, m_ref)

evaluator.evaluate()
# Out:
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and
# 		(handempty )
# 		(ontable ?o1)
# 		(clear ?o1)
# 	)
# 	:effects (and
# 		(not (ontable ?o1))
# 		(not (handempty ))
# 		(holding ?o1)
# 		(not (clear ?o1))
# 	)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and
# 		(holding ?o1)
# 	)
# 	:effects (and
# 		(ontable ?o1)
# 		(handempty )
# 		(not (holding ?o1))
# 		(clear ?o1)
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and
# 		(clear ?o2)
# 		(handempty )
# 		(on ?o2 ?o1)
# 		(holding ?o1)
# 	)
# 	:effects (and
# 		(not (clear ?o2))
# 		(clear ?o1)
# 		(not (on ?o2 ?o1))
# 		(holding ?o2)
# 		(on ?o1 ?o2)
# 		(not (holding ?o1))
# 		(handempty )
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and
# 		(handempty )
# 		(clear ?o1)
# 		(holding ?o2)
# 		(on ?o1 ?o2)
# 	)
# 	:effects (and
# 		(clear ?o2)
# 		(not (clear ?o1))
# 		(on ?o2 ?o1)
# 		(not (holding ?o2))
# 		(not (on ?o1 ?o2))
# 		(holding ?o1)
# 		(not (handempty ))
# 	)
# )
#
# F1 score: 0.7169811320754716
# PRE precision: 0.7, recall 0.7777777777777778
# ADD precision: 0.75, recall 0.6666666666666666
# DEL precision: 0.75, recall 0.6666666666666666
# AVG precision: 0.7307692307692307, recall 0.7037037037037037
# Matchings:
# 	Matching(pick-up, put-down, (0,))
# 	Matching(put-down, pick-up, (0,))
# 	Matching(stack, stack, (0, 1))
# 	Matching(unstack, unstack, (0, 1))

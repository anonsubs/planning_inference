# %%
from planning_inference.parsers import parse_model, parse_problem, parse_plan, parse_trajectory, parse_hypothesis, parse_observation_sequence
from planning_inference.generator import generate_trajectory
from planning_inference.functions import generate_all_literals, get_matching_literals

from planning_inference.pddl import Conjunction, Literal, Type, TypedObject, Effect, Truth, NumericConstant, PrimitiveNumericExpression, Increase
from planning_inference.pddl import SensorModel

from planning_inference.observations import Trajectory, Hypothesis, State

from planning_inference import DecodingTask

from sensor_models import load_sensor_model

import os
import copy
from collections import defaultdict
from itertools import combinations
from random import choice, choices, shuffle
from statistics import mean
import glob
import time

# %%
def launch_experiments(domain, task, timeout):
    Ms = load_sensor_model(domain)
    
    observabilities = [30, 50, 70]
       
    for observability in observabilities:
        base_path = "benchmark/%s/%s/%s/" % (domain, task, str(observability))

        problems = sorted(glob.glob(base_path + "*"))

        for problem in problems:
            costs = []
            times = []

            print(problem)

            # Planning Model
            Mp = parse_model(problem + "/domain")
            
            # Real Hypothesis
            with open(problem + "/sol", "r") as f:
                correct_h = int(f.read())

            print("Correct hypothesis: %d" % correct_h)

            # Observation sequence
#             obs = parse_observation_sequence(problem + "/obs")

            # Hypotheses
            h_files = sorted(glob.glob(problem + "/hyp*"))

            for i in range(len(h_files)):
                h = parse_LTLHypothesis(h_files[i])

                #Build a decoding problem for each hypothesis
                T = DecodingTaskLTL(Mp,Ms,h)

                tic = time.time()
                sol = T.decode(clean=True, planner="downward", t=timeout)
                toc = time.time()


                if len(sol.actions) == 0:
                    cost = 1000
                else:
                    cost = len(sol.actions)
                    sol.to_file(problem + "/plan.%s" % str(i).zfill(2))

                duration = toc - tic

                print("Hypothesis %d: %d, %.2f" % (i, cost, duration))

                costs.append(cost)
                times.append(duration)

            with open(problem + "/costs", "w") as f:
                f.write(" ".join(map(str, costs)))

            with open(problem + "/times", "w") as f:
                f.write(" ".join(map(str, times)))

# %%
domain = "driverlog"
timeout = 120

# %%
# MONITORING

task = "monitoring"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/driverlog/monitoring/30/P00
# Correct hypothesis: 3
# Hypothesis 0: 1000, 27.38
# Hypothesis 1: 27, 27.63
# Hypothesis 2: 28, 26.80
# Hypothesis 3: 27, 27.10
# Hypothesis 4: 1000, 27.81
# benchmark/driverlog/monitoring/30/P01
# Correct hypothesis: 2
# Hypothesis 0: 35, 32.63
# Hypothesis 1: 42, 32.90
# Hypothesis 2: 32, 30.53
# Hypothesis 3: 39, 32.77
# Hypothesis 4: 36, 31.91
# benchmark/driverlog/monitoring/30/P02
# Correct hypothesis: 2
# Hypothesis 0: 1000, 22.88
# Hypothesis 1: 1000, 23.41
# Hypothesis 2: 25, 22.76
# Hypothesis 3: 1000, 23.24
# Hypothesis 4: 1000, 23.02
# benchmark/driverlog/monitoring/30/P03
# Correct hypothesis: 1
# Hypothesis 0: 39, 31.36
# Hypothesis 1: 32, 30.25
# Hypothesis 2: 42, 31.83
# Hypothesis 3: 41, 32.26
# Hypothesis 4: 36, 31.88
# benchmark/driverlog/monitoring/30/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 27.68
# Hypothesis 1: 27, 28.01
# Hypothesis 2: 27, 27.27
# Hypothesis 3: 28, 26.74
# Hypothesis 4: 1000, 28.12
# Hypothesis 5: 1000, 27.37
# benchmark/driverlog/monitoring/30/P05
# Correct hypothesis: 1
# Hypothesis 0: 30, 31.11
# Hypothesis 1: 30, 31.14
# Hypothesis 2: 1000, 30.43
# Hypothesis 3: 31, 32.09
# Hypothesis 4: 1000, 32.01
# benchmark/driverlog/monitoring/30/P06
# Correct hypothesis: 2
# Hypothesis 0: 33, 22.62
# Hypothesis 1: 1000, 22.62
# Hypothesis 2: 22, 22.53
# Hypothesis 3: 1000, 22.63
# Hypothesis 4: 1000, 23.39
# benchmark/driverlog/monitoring/30/P07
# Correct hypothesis: 1
# Hypothesis 0: 41, 36.37
# Hypothesis 1: 36, 35.72
# Hypothesis 2: 35, 36.24
# Hypothesis 3: 42, 36.36
# Hypothesis 4: 36, 35.49
# Hypothesis 5: 42, 35.75
# benchmark/driverlog/monitoring/30/P08
# Correct hypothesis: 0
# Hypothesis 0: 31, 31.71
# Hypothesis 1: 1000, 31.88
# Hypothesis 2: 1000, 31.98
# Hypothesis 3: 1000, 31.55
# Hypothesis 4: 32, 32.09
# Hypothesis 5: 32, 31.21
# benchmark/driverlog/monitoring/30/P09
# Correct hypothesis: 5
# Hypothesis 0: 36, 37.97
# Hypothesis 1: 37, 34.36
# Hypothesis 2: 43, 36.07
# Hypothesis 3: 43, 36.02
# Hypothesis 4: 42, 34.79
# Hypothesis 5: 36, 34.47
# benchmark/driverlog/monitoring/50/P00
# Correct hypothesis: 3
# Hypothesis 0: 1000, 45.12
# Hypothesis 1: 31, 44.78
# Hypothesis 2: 33, 45.31
# Hypothesis 3: 31, 45.23
# Hypothesis 4: 1000, 45.43
# benchmark/driverlog/monitoring/50/P01
# Correct hypothesis: 2
# Hypothesis 0: 40, 54.07
# Hypothesis 1: 48, 56.51
# Hypothesis 2: 37, 55.48
# Hypothesis 3: 44, 55.07
# Hypothesis 4: 41, 55.28
# benchmark/driverlog/monitoring/50/P02
# Correct hypothesis: 2
# Hypothesis 0: 1000, 40.76
# Hypothesis 1: 1000, 41.20
# Hypothesis 2: 29, 40.27
# Hypothesis 3: 1000, 40.61
# Hypothesis 4: 1000, 40.60
# benchmark/driverlog/monitoring/50/P03
# Correct hypothesis: 1
# Hypothesis 0: 44, 55.92
# Hypothesis 1: 37, 54.45
# Hypothesis 2: 47, 54.81
# Hypothesis 3: 47, 55.57
# Hypothesis 4: 41, 54.29
# benchmark/driverlog/monitoring/50/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 45.80
# Hypothesis 1: 31, 45.06
# Hypothesis 2: 31, 44.84
# Hypothesis 3: 32, 44.94
# Hypothesis 4: 1000, 43.14
# Hypothesis 5: 1000, 45.77
# benchmark/driverlog/monitoring/50/P05
# Correct hypothesis: 1
# Hypothesis 0: 35, 53.92
# Hypothesis 1: 1000, 121.00
# Hypothesis 2: 1000, 54.73
# Hypothesis 3: 36, 53.21
# Hypothesis 4: 1000, 54.25
# benchmark/driverlog/monitoring/50/P06
# Correct hypothesis: 2
# Hypothesis 0: 36, 35.66
# Hypothesis 1: 1000, 36.27
# Hypothesis 2: 26, 34.57
# Hypothesis 3: 1000, 35.98
# Hypothesis 4: 1000, 36.46
# benchmark/driverlog/monitoring/50/P07
# Correct hypothesis: 1
# Hypothesis 0: 47, 64.62
# Hypothesis 1: 42, 63.75
# Hypothesis 2: 41, 62.55
# Hypothesis 3: 48, 60.51
# Hypothesis 4: 1000, 121.17
# Hypothesis 5: 48, 63.53
# benchmark/driverlog/monitoring/50/P08
# Correct hypothesis: 0
# Hypothesis 0: 36, 54.07
# Hypothesis 1: 1000, 55.06
# Hypothesis 2: 1000, 54.85
# Hypothesis 3: 1000, 56.14
# Hypothesis 4: 37, 53.63
# Hypothesis 5: 37, 53.97
# benchmark/driverlog/monitoring/50/P09
# Correct hypothesis: 5
# Hypothesis 0: 42, 66.00
# Hypothesis 1: 43, 62.26
# Hypothesis 2: 49, 64.33
# Hypothesis 3: 49, 64.69
# Hypothesis 4: 48, 64.76
# Hypothesis 5: 42, 61.56
# benchmark/driverlog/monitoring/70/P00
# Correct hypothesis: 3
# Hypothesis 0: 1000, 64.27
# Hypothesis 1: 34, 63.13
# Hypothesis 2: 36, 62.77
# Hypothesis 3: 34, 62.56
# Hypothesis 4: 1000, 63.57
# benchmark/driverlog/monitoring/70/P01
# Correct hypothesis: 2
# Hypothesis 0: 45, 72.70
# Hypothesis 1: 52, 74.25
# Hypothesis 2: 41, 75.65
# Hypothesis 3: 50, 72.45
# Hypothesis 4: 45, 74.71
# benchmark/driverlog/monitoring/70/P02
# Correct hypothesis: 2
# Hypothesis 0: 1000, 59.48
# Hypothesis 1: 1000, 56.52
# Hypothesis 2: 32, 59.36
# Hypothesis 3: 1000, 58.84
# Hypothesis 4: 1000, 56.35
# benchmark/driverlog/monitoring/70/P03
# Correct hypothesis: 1
# Hypothesis 0: 47, 73.32
# Hypothesis 1: 40, 72.52
# Hypothesis 2: 50, 72.14
# Hypothesis 3: 1000, 121.31
# Hypothesis 4: 1000, 121.32
# benchmark/driverlog/monitoring/70/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 63.47
# Hypothesis 1: 35, 65.58
# Hypothesis 2: 35, 64.15
# Hypothesis 3: 36, 63.57
# Hypothesis 4: 1000, 63.83
# Hypothesis 5: 1000, 64.23
# benchmark/driverlog/monitoring/70/P05
# Correct hypothesis: 1
# Hypothesis 0: 40, 71.66
# Hypothesis 1: 39, 71.83
# Hypothesis 2: 1000, 73.07
# Hypothesis 3: 40, 72.46
# Hypothesis 4: 1000, 70.34
# benchmark/driverlog/monitoring/70/P06
# Correct hypothesis: 2
# Hypothesis 0: 39, 49.68
# Hypothesis 1: 1000, 49.83
# Hypothesis 2: 29, 50.12
# Hypothesis 3: 1000, 50.84
# Hypothesis 4: 1000, 51.35
# benchmark/driverlog/monitoring/70/P07
# Correct hypothesis: 1
# Hypothesis 0: 53, 88.37
# Hypothesis 1: 47, 87.90
# Hypothesis 2: 47, 84.82
# Hypothesis 3: 54, 85.48
# Hypothesis 4: 47, 87.80
# Hypothesis 5: 53, 89.28
# benchmark/driverlog/monitoring/70/P08
# Correct hypothesis: 0
# Hypothesis 0: 40, 72.43
# Hypothesis 1: 1000, 73.16
# Hypothesis 2: 1000, 75.21
# Hypothesis 3: 1000, 71.63
# Hypothesis 4: 41, 72.12
# Hypothesis 5: 41, 71.98
# benchmark/driverlog/monitoring/70/P09
# Correct hypothesis: 5
# Hypothesis 0: 46, 86.92
# Hypothesis 1: 47, 82.62
# Hypothesis 2: 53, 86.08
# Hypothesis 3: 53, 83.82
# Hypothesis 4: 52, 88.77
# Hypothesis 5: 47, 87.49

# %%
# PREDICTION

task = "prediction"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/driverlog/prediction/30/P00
# Correct hypothesis: 4
# Hypothesis 0: 46, 22.32
# Hypothesis 1: 48, 22.92
# Hypothesis 2: 50, 23.27
# Hypothesis 3: 47, 22.75
# Hypothesis 4: 41, 23.09
# Hypothesis 5: 45, 23.12
# benchmark/driverlog/prediction/30/P01
# Correct hypothesis: 2
# Hypothesis 0: 48, 31.55
# Hypothesis 1: 49, 31.73
# Hypothesis 2: 43, 31.62
# Hypothesis 3: 46, 32.74
# Hypothesis 4: 46, 32.83
# benchmark/driverlog/prediction/30/P02
# Correct hypothesis: 3
# Hypothesis 0: 47, 23.36
# Hypothesis 1: 47, 22.81
# Hypothesis 2: 48, 24.62
# Hypothesis 3: 41, 23.47
# Hypothesis 4: 45, 23.03
# benchmark/driverlog/prediction/30/P03
# Correct hypothesis: 3
# Hypothesis 0: 49, 32.30
# Hypothesis 1: 47, 31.87
# Hypothesis 2: 49, 32.19
# Hypothesis 3: 44, 32.55
# Hypothesis 4: 47, 31.82
# benchmark/driverlog/prediction/30/P04
# Correct hypothesis: 1
# Hypothesis 0: 50, 22.77
# Hypothesis 1: 41, 21.93
# Hypothesis 2: 46, 23.37
# Hypothesis 3: 45, 23.20
# Hypothesis 4: 47, 23.95
# Hypothesis 5: 48, 23.05
# benchmark/driverlog/prediction/30/P05
# Correct hypothesis: 4
# Hypothesis 0: 48, 22.90
# Hypothesis 1: 47, 23.75
# Hypothesis 2: 47, 23.13
# Hypothesis 3: 47, 23.53
# Hypothesis 4: 41, 22.19
# benchmark/driverlog/prediction/30/P06
# Correct hypothesis: 3
# Hypothesis 0: 42, 22.78
# Hypothesis 1: 43, 22.95
# Hypothesis 2: 44, 23.31
# Hypothesis 3: 40, 21.63
# Hypothesis 4: 47, 23.17
# Hypothesis 5: 49, 23.04
# benchmark/driverlog/prediction/30/P07
# Correct hypothesis: 1
# Hypothesis 0: 1000, 120.96
# Hypothesis 1: 45, 33.33
# Hypothesis 2: 50, 33.09
# Hypothesis 3: 48, 32.35
# Hypothesis 4: 50, 31.81
# benchmark/driverlog/prediction/30/P08
# Correct hypothesis: 2
# Hypothesis 0: 44, 27.30
# Hypothesis 1: 44, 27.34
# Hypothesis 2: 42, 28.28
# Hypothesis 3: 44, 27.46
# Hypothesis 4: 45, 26.12
# benchmark/driverlog/prediction/30/P09
# Correct hypothesis: 1
# Hypothesis 0: 48, 32.35
# Hypothesis 1: 45, 32.38
# Hypothesis 2: 50, 31.79
# Hypothesis 3: 1000, 120.61
# Hypothesis 4: 1000, 120.61
# benchmark/driverlog/prediction/50/P00
# Correct hypothesis: 4
# Hypothesis 0: 49, 41.24
# Hypothesis 1: 51, 41.07
# Hypothesis 2: 53, 41.97
# Hypothesis 3: 50, 41.37
# Hypothesis 4: 44, 40.82
# Hypothesis 5: 48, 41.24
# benchmark/driverlog/prediction/50/P01
# Correct hypothesis: 2
# Hypothesis 0: 53, 56.72
# Hypothesis 1: 54, 54.89
# Hypothesis 2: 48, 55.92
# Hypothesis 3: 51, 55.58
# Hypothesis 4: 51, 54.98
# benchmark/driverlog/prediction/50/P02
# Correct hypothesis: 3
# Hypothesis 0: 50, 42.21
# Hypothesis 1: 50, 41.17
# Hypothesis 2: 51, 40.15
# Hypothesis 3: 44, 39.57
# Hypothesis 4: 48, 40.28
# benchmark/driverlog/prediction/50/P03
# Correct hypothesis: 3
# Hypothesis 0: 53, 53.99
# Hypothesis 1: 51, 55.18
# Hypothesis 2: 53, 54.25
# Hypothesis 3: 48, 55.23
# Hypothesis 4: 51, 57.28
# benchmark/driverlog/prediction/50/P04
# Correct hypothesis: 1
# Hypothesis 0: 54, 42.15
# Hypothesis 1: 45, 41.10
# Hypothesis 2: 50, 41.34
# Hypothesis 3: 49, 40.04
# Hypothesis 4: 51, 42.04
# Hypothesis 5: 52, 40.65
# benchmark/driverlog/prediction/50/P05
# Correct hypothesis: 4
# Hypothesis 0: 53, 41.22
# Hypothesis 1: 52, 41.02
# Hypothesis 2: 52, 42.40
# Hypothesis 3: 52, 41.61
# Hypothesis 4: 45, 41.14
# benchmark/driverlog/prediction/50/P06
# Correct hypothesis: 3
# Hypothesis 0: 45, 36.46
# Hypothesis 1: 46, 36.73
# Hypothesis 2: 47, 37.35
# Hypothesis 3: 43, 36.03
# Hypothesis 4: 50, 35.46
# Hypothesis 5: 52, 36.49
# benchmark/driverlog/prediction/50/P07
# Correct hypothesis: 1
# Hypothesis 0: 56, 60.97
# Hypothesis 1: 50, 61.14
# Hypothesis 2: 55, 60.26
# Hypothesis 3: 53, 59.55
# Hypothesis 4: 55, 58.72
# benchmark/driverlog/prediction/50/P08
# Correct hypothesis: 2
# Hypothesis 0: 47, 46.62
# Hypothesis 1: 49, 44.97
# Hypothesis 2: 45, 45.05
# Hypothesis 3: 47, 45.38
# Hypothesis 4: 48, 45.30
# benchmark/driverlog/prediction/50/P09
# Correct hypothesis: 1
# Hypothesis 0: 54, 60.13
# Hypothesis 1: 51, 59.40
# Hypothesis 2: 56, 61.76
# Hypothesis 3: 56, 59.33
# Hypothesis 4: 54, 60.09
# benchmark/driverlog/prediction/70/P00
# Correct hypothesis: 4
# Hypothesis 0: 51, 56.05
# Hypothesis 1: 53, 52.45
# Hypothesis 2: 55, 54.64
# Hypothesis 3: 52, 54.64
# Hypothesis 4: 46, 54.90
# Hypothesis 5: 50, 54.77
# benchmark/driverlog/prediction/70/P01
# Correct hypothesis: 2
# Hypothesis 0: 57, 73.17
# Hypothesis 1: 58, 70.60
# Hypothesis 2: 52, 74.27
# Hypothesis 3: 55, 75.19
# Hypothesis 4: 55, 74.56
# benchmark/driverlog/prediction/70/P02
# Correct hypothesis: 3
# Hypothesis 0: 54, 60.79
# Hypothesis 1: 56, 56.74
# Hypothesis 2: 55, 58.94
# Hypothesis 3: 1000, 121.09
# Hypothesis 4: 52, 60.05
# benchmark/driverlog/prediction/70/P03
# Correct hypothesis: 3
# Hypothesis 0: 56, 73.54
# Hypothesis 1: 54, 73.13
# Hypothesis 2: 56, 74.12
# Hypothesis 3: 51, 74.27
# Hypothesis 4: 54, 75.07
# benchmark/driverlog/prediction/70/P04
# Correct hypothesis: 1
# Hypothesis 0: 57, 52.50
# Hypothesis 1: 48, 55.63
# Hypothesis 2: 53, 54.64
# Hypothesis 3: 52, 52.82
# Hypothesis 4: 54, 55.89
# Hypothesis 5: 55, 54.56
# benchmark/driverlog/prediction/70/P05
# Correct hypothesis: 4
# Hypothesis 0: 55, 58.81
# Hypothesis 1: 54, 58.26
# Hypothesis 2: 54, 59.56
# Hypothesis 3: 56, 59.74
# Hypothesis 4: 1000, 121.82
# benchmark/driverlog/prediction/70/P06
# Correct hypothesis: 3
# Hypothesis 0: 47, 51.44
# Hypothesis 1: 48, 48.73
# Hypothesis 2: 49, 50.65
# Hypothesis 3: 45, 50.20
# Hypothesis 4: 52, 49.60
# Hypothesis 5: 54, 50.22
# benchmark/driverlog/prediction/70/P07
# Correct hypothesis: 1
# Hypothesis 0: 1000, 121.48
# Hypothesis 1: 55, 85.79
# Hypothesis 2: 60, 83.62
# Hypothesis 3: 58, 84.31
# Hypothesis 4: 60, 86.92
# benchmark/driverlog/prediction/70/P08
# Correct hypothesis: 2
# Hypothesis 0: 50, 64.59
# Hypothesis 1: 52, 63.25
# Hypothesis 2: 48, 63.88
# Hypothesis 3: 50, 65.26
# Hypothesis 4: 51, 64.31
# benchmark/driverlog/prediction/70/P09
# Correct hypothesis: 1
# Hypothesis 0: 58, 85.80
# Hypothesis 1: 55, 79.33
# Hypothesis 2: 60, 83.49
# Hypothesis 3: 60, 84.36
# Hypothesis 4: 58, 85.64

# %%
# HINDSIGHT

task = "hindsight"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/driverlog/hindsight/30/P00
# Correct hypothesis: 2
# Hypothesis 0: 1000, 121.07
# Hypothesis 1: 47, 41.25
# Hypothesis 2: 41, 40.64
# Hypothesis 3: 1000, 40.99
# Hypothesis 4: 45, 41.20
# benchmark/driverlog/hindsight/30/P01
# Correct hypothesis: 0
# Hypothesis 0: 42, 41.57
# Hypothesis 1: 1000, 40.98
# Hypothesis 2: 48, 40.72
# Hypothesis 3: 44, 40.66
# Hypothesis 4: 1000, 41.12
# benchmark/driverlog/hindsight/30/P02
# Correct hypothesis: 4
# Hypothesis 0: 44, 42.05
# Hypothesis 1: 1000, 40.37
# Hypothesis 2: 1000, 40.20
# Hypothesis 3: 45, 40.88
# Hypothesis 4: 39, 38.58
# benchmark/driverlog/hindsight/30/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 42.05
# Hypothesis 1: 1000, 40.34
# Hypothesis 2: 42, 40.73
# Hypothesis 3: 47, 40.94
# Hypothesis 4: 40, 41.18
# Hypothesis 5: 43, 41.13
# benchmark/driverlog/hindsight/30/P04
# Correct hypothesis: 0
# Hypothesis 0: 40, 39.11
# Hypothesis 1: 46, 41.63
# Hypothesis 2: 47, 40.97
# Hypothesis 3: 46, 40.74
# Hypothesis 4: 45, 41.12
# Hypothesis 5: 46, 40.61
# benchmark/driverlog/hindsight/30/P05
# Correct hypothesis: 1
# Hypothesis 0: 44, 41.06
# Hypothesis 1: 39, 40.23
# Hypothesis 2: 1000, 40.60
# Hypothesis 3: 1000, 120.77
# Hypothesis 4: 1000, 40.71
# benchmark/driverlog/hindsight/30/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 40.51
# Hypothesis 1: 51, 41.31
# Hypothesis 2: 43, 41.08
# Hypothesis 3: 39, 40.44
# Hypothesis 4: 1000, 40.96
# benchmark/driverlog/hindsight/30/P07
# Correct hypothesis: 2
# Hypothesis 0: 47, 45.59
# Hypothesis 1: 1000, 46.35
# Hypothesis 2: 45, 45.52
# Hypothesis 3: 1000, 46.65
# Hypothesis 4: 48, 47.18
# benchmark/driverlog/hindsight/30/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 40.11
# Hypothesis 1: 41, 40.05
# Hypothesis 2: 45, 41.34
# Hypothesis 3: 1000, 41.01
# Hypothesis 4: 58, 39.54
# benchmark/driverlog/hindsight/30/P09
# Correct hypothesis: 1
# Hypothesis 0: 48, 47.02
# Hypothesis 1: 45, 45.68
# Hypothesis 2: 1000, 45.67
# Hypothesis 3: 47, 46.45
# Hypothesis 4: 1000, 46.19
# Hypothesis 5: 53, 46.80
# benchmark/driverlog/hindsight/50/P00
# Correct hypothesis: 2
# Hypothesis 0: 1000, 71.25
# Hypothesis 1: 1000, 72.97
# Hypothesis 2: 47, 72.64
# Hypothesis 3: 1000, 71.81
# Hypothesis 4: 52, 74.74
# benchmark/driverlog/hindsight/50/P01
# Correct hypothesis: 0
# Hypothesis 0: 48, 75.02
# Hypothesis 1: 1000, 76.30
# Hypothesis 2: 56, 72.58
# Hypothesis 3: 50, 74.32
# Hypothesis 4: 1000, 70.16
# benchmark/driverlog/hindsight/50/P02
# Correct hypothesis: 4
# Hypothesis 0: 51, 72.68
# Hypothesis 1: 1000, 74.12
# Hypothesis 2: 1000, 72.54
# Hypothesis 3: 1000, 71.61
# Hypothesis 4: 45, 73.45
# benchmark/driverlog/hindsight/50/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 74.03
# Hypothesis 1: 1000, 72.91
# Hypothesis 2: 48, 72.62
# Hypothesis 3: 54, 74.60
# Hypothesis 4: 46, 74.07
# Hypothesis 5: 49, 73.95
# benchmark/driverlog/hindsight/50/P04
# Correct hypothesis: 0
# Hypothesis 0: 48, 74.67
# Hypothesis 1: 55, 70.87
# Hypothesis 2: 55, 75.55
# Hypothesis 3: 54, 74.01
# Hypothesis 4: 53, 74.29
# Hypothesis 5: 54, 74.15
# benchmark/driverlog/hindsight/50/P05
# Correct hypothesis: 1
# Hypothesis 0: 51, 74.00
# Hypothesis 1: 46, 74.57
# Hypothesis 2: 1000, 70.59
# Hypothesis 3: 1000, 73.50
# Hypothesis 4: 1000, 70.00
# benchmark/driverlog/hindsight/50/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 69.85
# Hypothesis 1: 60, 76.62
# Hypothesis 2: 51, 73.43
# Hypothesis 3: 46, 74.19
# Hypothesis 4: 1000, 74.16
# benchmark/driverlog/hindsight/50/P07
# Correct hypothesis: 2
# Hypothesis 0: 53, 81.40
# Hypothesis 1: 1000, 77.03
# Hypothesis 2: 51, 78.39
# Hypothesis 3: 1000, 82.69
# Hypothesis 4: 54, 77.75
# benchmark/driverlog/hindsight/50/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 73.17
# Hypothesis 1: 49, 72.56
# Hypothesis 2: 54, 72.91
# Hypothesis 3: 1000, 74.51
# Hypothesis 4: 68, 73.42
# benchmark/driverlog/hindsight/50/P09
# Correct hypothesis: 1
# Hypothesis 0: 54, 78.76
# Hypothesis 1: 51, 77.58
# Hypothesis 2: 1000, 79.69
# Hypothesis 3: 53, 79.12
# Hypothesis 4: 1000, 79.10
# Hypothesis 5: 1000, 121.39
# benchmark/driverlog/hindsight/70/P00
# Correct hypothesis: 2
# Hypothesis 0: 1000, 102.38
# Hypothesis 1: 1000, 102.68
# Hypothesis 2: 52, 103.22
# Hypothesis 3: 1000, 100.52
# Hypothesis 4: 57, 101.13
# benchmark/driverlog/hindsight/70/P01
# Correct hypothesis: 0
# Hypothesis 0: 55, 103.75
# Hypothesis 1: 1000, 102.99
# Hypothesis 2: 65, 108.52
# Hypothesis 3: 58, 108.12
# Hypothesis 4: 1000, 102.36
# benchmark/driverlog/hindsight/70/P02
# Correct hypothesis: 4
# Hypothesis 0: 58, 105.25
# Hypothesis 1: 1000, 102.95
# Hypothesis 2: 1000, 105.14
# Hypothesis 3: 1000, 101.33
# Hypothesis 4: 52, 97.59
# benchmark/driverlog/hindsight/70/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 104.15
# Hypothesis 1: 1000, 105.74
# Hypothesis 2: 57, 107.68
# Hypothesis 3: 63, 106.74
# Hypothesis 4: 54, 107.83
# Hypothesis 5: 57, 102.02
# benchmark/driverlog/hindsight/70/P04
# Correct hypothesis: 0
# Hypothesis 0: 52, 104.35
# Hypothesis 1: 65, 104.53
# Hypothesis 2: 1000, 102.69
# Hypothesis 3: 1000, 103.07
# Hypothesis 4: 57, 100.78
# Hypothesis 5: 61, 103.88
# benchmark/driverlog/hindsight/70/P05
# Correct hypothesis: 1
# Hypothesis 0: 57, 104.56
# Hypothesis 1: 52, 102.36
# Hypothesis 2: 1000, 105.41
# Hypothesis 3: 1000, 101.73
# Hypothesis 4: 1000, 101.96
# benchmark/driverlog/hindsight/70/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 106.35
# Hypothesis 1: 69, 102.83
# Hypothesis 2: 60, 103.17
# Hypothesis 3: 54, 101.56
# Hypothesis 4: 1000, 103.02
# benchmark/driverlog/hindsight/70/P07
# Correct hypothesis: 2
# Hypothesis 0: 60, 108.83
# Hypothesis 1: 1000, 113.10
# Hypothesis 2: 57, 117.85
# Hypothesis 3: 1000, 115.70
# Hypothesis 4: 1000, 121.93
# benchmark/driverlog/hindsight/70/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 102.56
# Hypothesis 1: 54, 106.91
# Hypothesis 2: 60, 100.79
# Hypothesis 3: 1000, 104.07
# Hypothesis 4: 76, 102.96
# benchmark/driverlog/hindsight/70/P09
# Correct hypothesis: 1
# Hypothesis 0: 61, 112.82
# Hypothesis 1: 56, 112.01
# Hypothesis 2: 1000, 113.81
# Hypothesis 3: 59, 113.61
# Hypothesis 4: 1000, 112.40
# Hypothesis 5: 69, 114.01

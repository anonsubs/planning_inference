# %%
from planning_inference.parsers import parse_model, parse_problem, parse_plan, parse_trajectory, parse_hypothesis, parse_observation_sequence
from planning_inference.generator import generate_trajectory
from planning_inference.functions import generate_all_literals, get_matching_literals

from planning_inference.pddl import Conjunction, Literal, Type, TypedObject, Effect, Truth, NumericConstant, PrimitiveNumericExpression, Increase
from planning_inference.pddl import SensorModel

from planning_inference.observations import Trajectory, Hypothesis, State

from planning_inference import DecodingTask

from sensor_models import load_sensor_model

import os
import copy
from collections import defaultdict
from itertools import combinations
from random import choice, choices, shuffle
from statistics import mean
import glob
import time

# %%
def launch_experiments(domain, task, timeout):
    Ms = load_sensor_model(domain)
    
    observabilities = [30, 50, 70]
       
    for observability in observabilities:
        base_path = "benchmark/%s/%s/%s/" % (domain, task, str(observability))

        problems = sorted(glob.glob(base_path + "*"))

        for problem in problems:
            costs = []
            times = []

            print(problem)

            # Planning Model
            Mp = parse_model(problem + "/domain")
            
            # Real Hypothesis
            with open(problem + "/sol", "r") as f:
                correct_h = int(f.read())

            print("Correct hypothesis: %d" % correct_h)

            # Observation sequence
#             obs = parse_observation_sequence(problem + "/obs")

            # Hypotheses
            h_files = sorted(glob.glob(problem + "/hyp*"))

            for i in range(len(h_files)):
                h = parse_LTLHypothesis(h_files[i])

                #Build a decoding problem for each hypothesis
                T = DecodingTaskLTL(Mp,Ms,h)

                tic = time.time()
                sol = T.decode(clean=True, planner="downward", t=timeout)
                toc = time.time()


                if len(sol.actions) == 0:
                    cost = 1000
                else:
                    cost = len(sol.actions)
                    sol.to_file(problem + "/plan.%s" % str(i).zfill(2))

                duration = toc - tic

                print("Hypothesis %d: %d, %.2f" % (i, cost, duration))

                costs.append(cost)
                times.append(duration)

            with open(problem + "/costs", "w") as f:
                f.write(" ".join(map(str, costs)))

            with open(problem + "/times", "w") as f:
                f.write(" ".join(map(str, times)))

# %%
domain = "miconic"
timeout = 120

# %%
# MONITORING

task = "monitoring"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/miconic/monitoring/30/P00
# Correct hypothesis: 3
# Hypothesis 0: 21, 3.83
# Hypothesis 1: 21, 4.92
# Hypothesis 2: 19, 2.54
# Hypothesis 3: 19, 2.20
# Hypothesis 4: 20, 5.35
# Hypothesis 5: 21, 5.17
# benchmark/miconic/monitoring/30/P01
# Correct hypothesis: 4
# Hypothesis 0: 19, 4.15
# Hypothesis 1: 20, 3.39
# Hypothesis 2: 19, 5.34
# Hypothesis 3: 20, 4.38
# Hypothesis 4: 18, 4.36
# Hypothesis 5: 19, 5.72
# benchmark/miconic/monitoring/30/P02
# Correct hypothesis: 2
# Hypothesis 0: 22, 6.46
# Hypothesis 1: 22, 6.73
# Hypothesis 2: 20, 6.34
# Hypothesis 3: 22, 8.41
# Hypothesis 4: 22, 7.90
# Hypothesis 5: 22, 7.03
# benchmark/miconic/monitoring/30/P03
# Correct hypothesis: 0
# Hypothesis 0: 16, 2.19
# Hypothesis 1: 19, 2.46
# Hypothesis 2: 21, 4.68
# Hypothesis 3: 18, 1.69
# Hypothesis 4: 19, 1.99
# Hypothesis 5: 19, 1.77
# benchmark/miconic/monitoring/30/P04
# Correct hypothesis: 3
# Hypothesis 0: 1000, 120.09
# Hypothesis 1: 20, 7.01
# Hypothesis 2: 21, 5.88
# Hypothesis 3: 19, 4.92
# Hypothesis 4: 21, 5.15
# Hypothesis 5: 20, 4.38
# benchmark/miconic/monitoring/30/P05
# Correct hypothesis: 1
# Hypothesis 0: 24, 18.45
# Hypothesis 1: 20, 4.06
# Hypothesis 2: 21, 4.46
# Hypothesis 3: 21, 5.98
# Hypothesis 4: 23, 10.97
# Hypothesis 5: 22, 7.95
# benchmark/miconic/monitoring/30/P06
# Correct hypothesis: 3
# Hypothesis 0: 23, 24.78
# Hypothesis 1: 22, 12.79
# Hypothesis 2: 24, 32.15
# Hypothesis 3: 21, 6.52
# Hypothesis 4: 23, 15.19
# Hypothesis 5: 22, 8.52
# benchmark/miconic/monitoring/30/P07
# Correct hypothesis: 5
# Hypothesis 0: 21, 4.71
# Hypothesis 1: 21, 4.77
# Hypothesis 2: 23, 10.67
# Hypothesis 3: 21, 4.83
# Hypothesis 4: 22, 5.80
# Hypothesis 5: 20, 4.04
# benchmark/miconic/monitoring/30/P08
# Correct hypothesis: 1
# Hypothesis 0: 20, 4.16
# Hypothesis 1: 18, 2.68
# Hypothesis 2: 20, 3.03
# Hypothesis 3: 20, 2.80
# Hypothesis 4: 20, 3.35
# Hypothesis 5: 19, 2.45
# benchmark/miconic/monitoring/30/P09
# Correct hypothesis: 1
# Hypothesis 0: 23, 7.39
# Hypothesis 1: 20, 2.27
# Hypothesis 2: 23, 7.25
# Hypothesis 3: 25, 30.09
# Hypothesis 4: 24, 18.20
# Hypothesis 5: 23, 5.41
# benchmark/miconic/monitoring/50/P00
# Correct hypothesis: 3
# Hypothesis 0: 25, 7.89
# Hypothesis 1: 25, 10.71
# Hypothesis 2: 26, 25.08
# Hypothesis 3: 22, 3.39
# Hypothesis 4: 25, 13.46
# Hypothesis 5: 24, 5.06
# benchmark/miconic/monitoring/50/P01
# Correct hypothesis: 4
# Hypothesis 0: 22, 6.07
# Hypothesis 1: 1000, 120.10
# Hypothesis 2: 1000, 120.10
# Hypothesis 3: 23, 5.72
# Hypothesis 4: 21, 6.33
# Hypothesis 5: 1000, 120.10
# benchmark/miconic/monitoring/50/P02
# Correct hypothesis: 2
# Hypothesis 0: 25, 11.97
# Hypothesis 1: 25, 12.64
# Hypothesis 2: 22, 6.57
# Hypothesis 3: 1000, 120.10
# Hypothesis 4: 24, 8.16
# Hypothesis 5: 25, 13.40
# benchmark/miconic/monitoring/50/P03
# Correct hypothesis: 0
# Hypothesis 0: 1000, 120.09
# Hypothesis 1: 21, 4.10
# Hypothesis 2: 24, 15.11
# Hypothesis 3: 20, 3.38
# Hypothesis 4: 21, 4.15
# Hypothesis 5: 21, 3.75
# benchmark/miconic/monitoring/50/P04
# Correct hypothesis: 3
# Hypothesis 0: 22, 6.36
# Hypothesis 1: 23, 7.16
# Hypothesis 2: 24, 8.67
# Hypothesis 3: 22, 6.85
# Hypothesis 4: 24, 8.10
# Hypothesis 5: 23, 6.01
# benchmark/miconic/monitoring/50/P05
# Correct hypothesis: 1
# Hypothesis 0: 27, 24.60
# Hypothesis 1: 23, 5.60
# Hypothesis 2: 24, 6.25
# Hypothesis 3: 24, 8.26
# Hypothesis 4: 27, 30.93
# Hypothesis 5: 25, 12.45
# benchmark/miconic/monitoring/50/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 121.02
# Hypothesis 1: 1000, 120.12
# Hypothesis 2: 28, 64.79
# Hypothesis 3: 24, 7.13
# Hypothesis 4: 27, 33.07
# Hypothesis 5: 26, 17.58
# benchmark/miconic/monitoring/50/P07
# Correct hypothesis: 5
# Hypothesis 0: 1000, 120.10
# Hypothesis 1: 23, 6.13
# Hypothesis 2: 25, 10.23
# Hypothesis 3: 23, 5.95
# Hypothesis 4: 25, 10.42
# Hypothesis 5: 22, 5.35
# benchmark/miconic/monitoring/50/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 120.10
# Hypothesis 1: 20, 4.41
# Hypothesis 2: 23, 5.22
# Hypothesis 3: 22, 4.11
# Hypothesis 4: 1000, 120.10
# Hypothesis 5: 21, 3.82
# benchmark/miconic/monitoring/50/P09
# Correct hypothesis: 1
# Hypothesis 0: 26, 11.86
# Hypothesis 1: 23, 3.67
# Hypothesis 2: 27, 23.07
# Hypothesis 3: 30, 108.92
# Hypothesis 4: 29, 77.67
# Hypothesis 5: 27, 15.98
# benchmark/miconic/monitoring/70/P00
# Correct hypothesis: 3
# Hypothesis 0: 27, 8.76
# Hypothesis 1: 27, 12.02
# Hypothesis 2: 28, 23.43
# Hypothesis 3: 24, 4.85
# Hypothesis 4: 27, 15.53
# Hypothesis 5: 26, 5.55
# benchmark/miconic/monitoring/70/P01
# Correct hypothesis: 4
# Hypothesis 0: 26, 12.35
# Hypothesis 1: 26, 9.75
# Hypothesis 2: 24, 9.37
# Hypothesis 3: 25, 7.47
# Hypothesis 4: 23, 8.10
# Hypothesis 5: 24, 9.17
# benchmark/miconic/monitoring/70/P02
# Correct hypothesis: 2
# Hypothesis 0: 28, 19.97
# Hypothesis 1: 1000, 120.13
# Hypothesis 2: 25, 8.86
# Hypothesis 3: 27, 17.82
# Hypothesis 4: 27, 16.31
# Hypothesis 5: 29, 17.97
# benchmark/miconic/monitoring/70/P03
# Correct hypothesis: 0
# Hypothesis 0: 21, 4.86
# Hypothesis 1: 25, 6.46
# Hypothesis 2: 27, 13.39
# Hypothesis 3: 24, 4.57
# Hypothesis 4: 25, 5.72
# Hypothesis 5: 25, 5.35
# benchmark/miconic/monitoring/70/P04
# Correct hypothesis: 3
# Hypothesis 0: 25, 7.04
# Hypothesis 1: 26, 7.55
# Hypothesis 2: 28, 48.30
# Hypothesis 3: 25, 8.13
# Hypothesis 4: 1000, 120.12
# Hypothesis 5: 27, 9.66
# benchmark/miconic/monitoring/70/P05
# Correct hypothesis: 1
# Hypothesis 0: 29, 21.93
# Hypothesis 1: 25, 6.64
# Hypothesis 2: 26, 7.28
# Hypothesis 3: 27, 12.57
# Hypothesis 4: 29, 22.57
# Hypothesis 5: 28, 22.10
# benchmark/miconic/monitoring/70/P06
# Correct hypothesis: 3
# Hypothesis 0: 30, 61.03
# Hypothesis 1: 28, 12.99
# Hypothesis 2: 32, 52.23
# Hypothesis 3: 27, 7.39
# Hypothesis 4: 30, 18.63
# Hypothesis 5: 29, 12.64
# benchmark/miconic/monitoring/70/P07
# Correct hypothesis: 5
# Hypothesis 0: 27, 9.61
# Hypothesis 1: 26, 7.56
# Hypothesis 2: 28, 10.75
# Hypothesis 3: 26, 7.42
# Hypothesis 4: 28, 11.67
# Hypothesis 5: 25, 6.76
# benchmark/miconic/monitoring/70/P08
# Correct hypothesis: 1
# Hypothesis 0: 28, 34.80
# Hypothesis 1: 23, 4.89
# Hypothesis 2: 27, 11.95
# Hypothesis 3: 25, 5.64
# Hypothesis 4: 26, 10.73
# Hypothesis 5: 23, 5.03
# benchmark/miconic/monitoring/70/P09
# Correct hypothesis: 1
# Hypothesis 0: 30, 18.74
# Hypothesis 1: 26, 5.07
# Hypothesis 2: 30, 23.95
# Hypothesis 3: 1000, 123.58
# Hypothesis 4: 32, 61.55
# Hypothesis 5: 30, 14.97

# %%
# PREDICTION

task = "prediction"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/miconic/prediction/30/P00
# Correct hypothesis: 2
# Hypothesis 0: 29, 8.45
# Hypothesis 1: 29, 7.75
# Hypothesis 2: 29, 8.57
# Hypothesis 3: 30, 10.45
# Hypothesis 4: 30, 14.06
# benchmark/miconic/prediction/30/P01
# Correct hypothesis: 2
# Hypothesis 0: 32, 23.17
# Hypothesis 1: 32, 43.47
# Hypothesis 2: 32, 56.48
# Hypothesis 3: 32, 20.91
# Hypothesis 4: 32, 35.66
# benchmark/miconic/prediction/30/P02
# Correct hypothesis: 0
# Hypothesis 0: 31, 16.93
# Hypothesis 1: 31, 17.00
# Hypothesis 2: 31, 19.72
# Hypothesis 3: 31, 19.65
# Hypothesis 4: 31, 19.44
# benchmark/miconic/prediction/30/P03
# Correct hypothesis: 4
# Hypothesis 0: 32, 30.50
# Hypothesis 1: 32, 30.20
# Hypothesis 2: 31, 16.23
# Hypothesis 3: 32, 31.21
# Hypothesis 4: 31, 16.21
# benchmark/miconic/prediction/30/P04
# Correct hypothesis: 2
# Hypothesis 0: 31, 10.18
# Hypothesis 1: 32, 13.86
# Hypothesis 2: 31, 10.20
# Hypothesis 3: 32, 30.31
# Hypothesis 4: 32, 29.99
# benchmark/miconic/prediction/30/P05
# Correct hypothesis: 3
# Hypothesis 0: 32, 45.92
# Hypothesis 1: 32, 42.18
# Hypothesis 2: 33, 101.76
# Hypothesis 3: 32, 48.66
# Hypothesis 4: 33, 93.85
# benchmark/miconic/prediction/30/P06
# Correct hypothesis: 1
# Hypothesis 0: 33, 33.73
# Hypothesis 1: 32, 17.95
# Hypothesis 2: 33, 32.07
# Hypothesis 3: 32, 19.28
# Hypothesis 4: 32, 22.07
# benchmark/miconic/prediction/30/P07
# Correct hypothesis: 0
# Hypothesis 0: 32, 19.15
# Hypothesis 1: 32, 16.86
# Hypothesis 2: 32, 19.83
# Hypothesis 3: 33, 38.12
# Hypothesis 4: 33, 40.91
# benchmark/miconic/prediction/30/P08
# Correct hypothesis: 1
# Hypothesis 0: 32, 29.37
# Hypothesis 1: 31, 15.64
# Hypothesis 2: 32, 28.49
# Hypothesis 3: 32, 28.68
# Hypothesis 4: 31, 15.65
# benchmark/miconic/prediction/30/P09
# Correct hypothesis: 4
# Hypothesis 0: 1000, 120.08
# Hypothesis 1: 31, 9.68
# Hypothesis 2: 31, 10.63
# Hypothesis 3: 30, 7.28
# Hypothesis 4: 30, 7.28
# benchmark/miconic/prediction/50/P00
# Correct hypothesis: 2
# Hypothesis 0: 33, 15.18
# Hypothesis 1: 33, 10.65
# Hypothesis 2: 33, 12.00
# Hypothesis 3: 34, 25.28
# Hypothesis 4: 34, 20.89
# benchmark/miconic/prediction/50/P01
# Correct hypothesis: 2
# Hypothesis 0: 35, 79.11
# Hypothesis 1: 36, 89.00
# Hypothesis 2: 35, 75.55
# Hypothesis 3: 35, 50.51
# Hypothesis 4: 36, 105.22
# benchmark/miconic/prediction/50/P02
# Correct hypothesis: 0
# Hypothesis 0: 35, 22.64
# Hypothesis 1: 35, 22.52
# Hypothesis 2: 35, 23.59
# Hypothesis 3: 35, 23.08
# Hypothesis 4: 35, 23.62
# benchmark/miconic/prediction/50/P03
# Correct hypothesis: 4
# Hypothesis 0: 36, 114.23
# Hypothesis 1: 36, 114.93
# Hypothesis 2: 35, 51.71
# Hypothesis 3: 36, 116.24
# Hypothesis 4: 35, 51.94
# benchmark/miconic/prediction/50/P04
# Correct hypothesis: 2
# Hypothesis 0: 34, 12.09
# Hypothesis 1: 35, 17.72
# Hypothesis 2: 34, 12.17
# Hypothesis 3: 35, 34.72
# Hypothesis 4: 35, 34.49
# benchmark/miconic/prediction/50/P05
# Correct hypothesis: 3
# Hypothesis 0: 35, 113.35
# Hypothesis 1: 34, 52.65
# Hypothesis 2: 1000, 120.10
# Hypothesis 3: 34, 54.57
# Hypothesis 4: 1000, 123.03
# benchmark/miconic/prediction/50/P06
# Correct hypothesis: 1
# Hypothesis 0: 36, 58.47
# Hypothesis 1: 35, 36.17
# Hypothesis 2: 36, 69.92
# Hypothesis 3: 35, 29.61
# Hypothesis 4: 36, 71.50
# benchmark/miconic/prediction/50/P07
# Correct hypothesis: 0
# Hypothesis 0: 36, 24.74
# Hypothesis 1: 36, 21.87
# Hypothesis 2: 36, 24.93
# Hypothesis 3: 37, 56.79
# Hypothesis 4: 37, 54.76
# benchmark/miconic/prediction/50/P08
# Correct hypothesis: 1
# Hypothesis 0: 35, 79.28
# Hypothesis 1: 34, 37.15
# Hypothesis 2: 35, 85.17
# Hypothesis 3: 35, 77.70
# Hypothesis 4: 34, 38.78
# benchmark/miconic/prediction/50/P09
# Correct hypothesis: 4
# Hypothesis 0: 35, 13.78
# Hypothesis 1: 1000, 120.11
# Hypothesis 2: 35, 13.42
# Hypothesis 3: 34, 9.19
# Hypothesis 4: 34, 9.48
# benchmark/miconic/prediction/70/P00
# Correct hypothesis: 2
# Hypothesis 0: 36, 19.01
# Hypothesis 1: 36, 18.75
# Hypothesis 2: 1000, 120.12
# Hypothesis 3: 37, 21.04
# Hypothesis 4: 37, 42.70
# benchmark/miconic/prediction/70/P01
# Correct hypothesis: 2
# Hypothesis 0: 38, 84.55
# Hypothesis 1: 1000, 123.85
# Hypothesis 2: 38, 87.34
# Hypothesis 3: 38, 57.57
# Hypothesis 4: 39, 120.69
# benchmark/miconic/prediction/70/P02
# Correct hypothesis: 0
# Hypothesis 0: 38, 25.43
# Hypothesis 1: 38, 25.19
# Hypothesis 2: 38, 25.40
# Hypothesis 3: 38, 25.57
# Hypothesis 4: 38, 25.30
# benchmark/miconic/prediction/70/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 124.56
# Hypothesis 1: 1000, 124.26
# Hypothesis 2: 38, 69.31
# Hypothesis 3: 1000, 124.43
# Hypothesis 4: 38, 66.41
# benchmark/miconic/prediction/70/P04
# Correct hypothesis: 2
# Hypothesis 0: 36, 13.68
# Hypothesis 1: 37, 27.41
# Hypothesis 2: 36, 13.64
# Hypothesis 3: 37, 40.99
# Hypothesis 4: 37, 42.67
# benchmark/miconic/prediction/70/P05
# Correct hypothesis: 3
# Hypothesis 0: 1000, 124.54
# Hypothesis 1: 38, 77.92
# Hypothesis 2: 1000, 120.15
# Hypothesis 3: 38, 77.73
# Hypothesis 4: 1000, 124.65
# benchmark/miconic/prediction/70/P06
# Correct hypothesis: 1
# Hypothesis 0: 39, 114.24
# Hypothesis 1: 38, 52.69
# Hypothesis 2: 39, 110.71
# Hypothesis 3: 38, 53.24
# Hypothesis 4: 39, 119.89
# benchmark/miconic/prediction/70/P07
# Correct hypothesis: 0
# Hypothesis 0: 40, 37.28
# Hypothesis 1: 40, 37.63
# Hypothesis 2: 40, 38.41
# Hypothesis 3: 41, 82.91
# Hypothesis 4: 41, 80.35
# benchmark/miconic/prediction/70/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 124.25
# Hypothesis 1: 37, 64.68
# Hypothesis 2: 1000, 124.24
# Hypothesis 3: 1000, 124.19
# Hypothesis 4: 37, 66.23
# benchmark/miconic/prediction/70/P09
# Correct hypothesis: 4
# Hypothesis 0: 37, 17.83
# Hypothesis 1: 37, 18.04
# Hypothesis 2: 37, 17.93
# Hypothesis 3: 36, 11.43
# Hypothesis 4: 36, 11.69

# %%
# HINDSIGHT

task = "hindsight"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/miconic/hindsight/30/P00
# Correct hypothesis: 2
# Hypothesis 0: 23, 7.62
# Hypothesis 1: 25, 22.26
# Hypothesis 2: 23, 7.90
# Hypothesis 3: 26, 45.58
# Hypothesis 4: 25, 21.88
# benchmark/miconic/hindsight/30/P01
# Correct hypothesis: 1
# Hypothesis 0: 21, 2.47
# Hypothesis 1: 19, 2.04
# Hypothesis 2: 23, 5.43
# Hypothesis 3: 21, 2.50
# Hypothesis 4: 19, 2.01
# benchmark/miconic/hindsight/30/P02
# Correct hypothesis: 1
# Hypothesis 0: 27, 34.34
# Hypothesis 1: 24, 7.11
# Hypothesis 2: 25, 11.94
# Hypothesis 3: 25, 11.21
# Hypothesis 4: 25, 11.53
# benchmark/miconic/hindsight/30/P03
# Correct hypothesis: 0
# Hypothesis 0: 1000, 120.10
# Hypothesis 1: 26, 53.91
# Hypothesis 2: 27, 82.29
# Hypothesis 3: 1000, 121.75
# Hypothesis 4: 27, 82.28
# benchmark/miconic/hindsight/30/P04
# Correct hypothesis: 3
# Hypothesis 0: 24, 8.64
# Hypothesis 1: 24, 8.55
# Hypothesis 2: 24, 8.18
# Hypothesis 3: 24, 8.16
# Hypothesis 4: 24, 8.10
# benchmark/miconic/hindsight/30/P05
# Correct hypothesis: 2
# Hypothesis 0: 26, 8.18
# Hypothesis 1: 27, 14.81
# Hypothesis 2: 25, 5.75
# Hypothesis 3: 27, 18.22
# Hypothesis 4: 29, 56.48
# benchmark/miconic/hindsight/30/P06
# Correct hypothesis: 4
# Hypothesis 0: 22, 6.51
# Hypothesis 1: 23, 10.89
# Hypothesis 2: 23, 10.84
# Hypothesis 3: 23, 12.19
# Hypothesis 4: 22, 6.23
# benchmark/miconic/hindsight/30/P07
# Correct hypothesis: 2
# Hypothesis 0: 1000, 122.07
# Hypothesis 1: 1000, 122.08
# Hypothesis 2: 32, 102.20
# Hypothesis 3: 1000, 122.08
# Hypothesis 4: 1000, 122.09
# benchmark/miconic/hindsight/30/P08
# Correct hypothesis: 2
# Hypothesis 0: 21, 3.59
# Hypothesis 1: 19, 2.10
# Hypothesis 2: 19, 2.08
# Hypothesis 3: 21, 3.57
# Hypothesis 4: 21, 3.47
# benchmark/miconic/hindsight/30/P09
# Correct hypothesis: 3
# Hypothesis 0: 25, 9.86
# Hypothesis 1: 23, 3.61
# Hypothesis 2: 25, 10.02
# Hypothesis 3: 23, 3.66
# Hypothesis 4: 25, 10.08
# benchmark/miconic/hindsight/50/P00
# Correct hypothesis: 2
# Hypothesis 0: 26, 5.11
# Hypothesis 1: 28, 10.93
# Hypothesis 2: 26, 5.82
# Hypothesis 3: 30, 41.80
# Hypothesis 4: 28, 10.94
# benchmark/miconic/hindsight/50/P01
# Correct hypothesis: 1
# Hypothesis 0: 23, 3.03
# Hypothesis 1: 21, 2.92
# Hypothesis 2: 25, 4.07
# Hypothesis 3: 23, 3.03
# Hypothesis 4: 21, 2.91
# benchmark/miconic/hindsight/50/P02
# Correct hypothesis: 1
# Hypothesis 0: 34, 47.72
# Hypothesis 1: 28, 3.79
# Hypothesis 2: 30, 5.25
# Hypothesis 3: 32, 13.21
# Hypothesis 4: 31, 7.48
# benchmark/miconic/hindsight/50/P03
# Correct hypothesis: 0
# Hypothesis 0: 31, 15.34
# Hypothesis 1: 31, 15.49
# Hypothesis 2: 34, 109.76
# Hypothesis 3: 1000, 123.05
# Hypothesis 4: 34, 111.32
# benchmark/miconic/hindsight/50/P04
# Correct hypothesis: 3
# Hypothesis 0: 28, 4.03
# Hypothesis 1: 28, 4.12
# Hypothesis 2: 28, 4.36
# Hypothesis 3: 28, 4.05
# Hypothesis 4: 28, 4.03
# benchmark/miconic/hindsight/50/P05
# Correct hypothesis: 2
# Hypothesis 0: 28, 19.62
# Hypothesis 1: 30, 69.32
# Hypothesis 2: 26, 7.69
# Hypothesis 3: 30, 86.20
# Hypothesis 4: 1000, 122.65
# benchmark/miconic/hindsight/50/P06
# Correct hypothesis: 4
# Hypothesis 0: 25, 3.95
# Hypothesis 1: 26, 5.21
# Hypothesis 2: 26, 5.25
# Hypothesis 3: 26, 5.39
# Hypothesis 4: 25, 4.00
# benchmark/miconic/hindsight/50/P07
# Correct hypothesis: 2
# Hypothesis 0: 39, 107.26
# Hypothesis 1: 1000, 123.71
# Hypothesis 2: 36, 14.97
# Hypothesis 3: 1000, 123.80
# Hypothesis 4: 38, 50.47
# benchmark/miconic/hindsight/50/P08
# Correct hypothesis: 2
# Hypothesis 0: 22, 4.35
# Hypothesis 1: 20, 2.93
# Hypothesis 2: 20, 2.97
# Hypothesis 3: 22, 4.35
# Hypothesis 4: 22, 4.29
# benchmark/miconic/hindsight/50/P09
# Correct hypothesis: 3
# Hypothesis 0: 28, 20.72
# Hypothesis 1: 24, 3.73
# Hypothesis 2: 28, 20.64
# Hypothesis 3: 24, 3.66
# Hypothesis 4: 28, 21.68
# benchmark/miconic/hindsight/70/P00
# Correct hypothesis: 2
# Hypothesis 0: 28, 5.43
# Hypothesis 1: 30, 9.97
# Hypothesis 2: 28, 5.54
# Hypothesis 3: 32, 37.81
# Hypothesis 4: 30, 9.99
# benchmark/miconic/hindsight/70/P01
# Correct hypothesis: 1
# Hypothesis 0: 26, 4.06
# Hypothesis 1: 22, 3.62
# Hypothesis 2: 26, 4.02
# Hypothesis 3: 26, 4.16
# Hypothesis 4: 22, 3.60
# benchmark/miconic/hindsight/70/P02
# Correct hypothesis: 1
# Hypothesis 0: 36, 19.15
# Hypothesis 1: 30, 4.87
# Hypothesis 2: 34, 8.42
# Hypothesis 3: 36, 22.12
# Hypothesis 4: 33, 5.54
# benchmark/miconic/hindsight/70/P03
# Correct hypothesis: 0
# Hypothesis 0: 33, 6.96
# Hypothesis 1: 1000, 120.15
# Hypothesis 2: 36, 28.03
# Hypothesis 3: 37, 47.10
# Hypothesis 4: 36, 27.99
# benchmark/miconic/hindsight/70/P04
# Correct hypothesis: 3
# Hypothesis 0: 29, 4.98
# Hypothesis 1: 29, 4.89
# Hypothesis 2: 29, 4.88
# Hypothesis 3: 29, 4.93
# Hypothesis 4: 29, 5.02
# benchmark/miconic/hindsight/70/P05
# Correct hypothesis: 2
# Hypothesis 0: 31, 10.91
# Hypothesis 1: 1000, 120.12
# Hypothesis 2: 29, 5.75
# Hypothesis 3: 33, 43.80
# Hypothesis 4: 1000, 120.23
# benchmark/miconic/hindsight/70/P06
# Correct hypothesis: 4
# Hypothesis 0: 28, 4.52
# Hypothesis 1: 29, 4.78
# Hypothesis 2: 31, 7.26
# Hypothesis 3: 29, 4.91
# Hypothesis 4: 28, 4.58
# benchmark/miconic/hindsight/70/P07
# Correct hypothesis: 2
# Hypothesis 0: 43, 42.98
# Hypothesis 1: 44, 69.64
# Hypothesis 2: 39, 7.02
# Hypothesis 3: 1000, 125.09
# Hypothesis 4: 43, 35.09
# benchmark/miconic/hindsight/70/P08
# Correct hypothesis: 2
# Hypothesis 0: 27, 8.39
# Hypothesis 1: 23, 3.90
# Hypothesis 2: 23, 3.93
# Hypothesis 3: 27, 8.24
# Hypothesis 4: 27, 7.87
# benchmark/miconic/hindsight/70/P09
# Correct hypothesis: 3
# Hypothesis 0: 30, 14.46
# Hypothesis 1: 1000, 120.12
# Hypothesis 2: 30, 14.53
# Hypothesis 3: 26, 4.50
# Hypothesis 4: 30, 14.34

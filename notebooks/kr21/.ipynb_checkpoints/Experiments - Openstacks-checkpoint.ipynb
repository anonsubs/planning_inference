# %%
from planning_inference.parsers import parse_model, parse_problem, parse_plan, parse_trajectory, parse_LTLHypothesis, parse_observation_sequence
from planning_inference.generator import generate_trajectory
from planning_inference.functions import generate_all_literals, get_matching_literals

from planning_inference.pddl import Conjunction, Literal, Type, TypedObject, Effect, Truth, NumericConstant, PrimitiveNumericExpression, Increase
from planning_inference.pddl import SensorModel

from planning_inference.observations import Trajectory, Hypothesis, State

from planning_inference import DecodingTaskLTL

from sensor_models import load_sensor_model

import os
import copy
from collections import defaultdict
from itertools import combinations
from random import choice, choices, shuffle
from statistics import mean
import glob
import time

# %%
def launch_experiments(domain, task, timeout):
    Ms = load_sensor_model(domain)
    
    observabilities = [30, 50, 70]
       
    for observability in observabilities:
        base_path = "benchmark/%s/%s/%s/" % (domain, task, str(observability))

        problems = sorted(glob.glob(base_path + "*"))

        for problem in problems:
            costs = []
            times = []

            print(problem)

            # Planning Model
            Mp = parse_model(problem + "/domain")
            
            # Real Hypothesis
            with open(problem + "/sol", "r") as f:
                correct_h = int(f.read())

            print("Correct hypothesis: %d" % correct_h)

            # Observation sequence
#             obs = parse_observation_sequence(problem + "/obs")

            # Hypotheses
            h_files = sorted(glob.glob(problem + "/hyp*"))

            for i in range(len(h_files)):
                h = parse_LTLHypothesis(h_files[i])

                #Build a decoding problem for each hypothesis
                T = DecodingTaskLTL(Mp,Ms,h)

                tic = time.time()
                sol = T.decode(clean=True, planner="downward", t=timeout)
                toc = time.time()


                if len(sol.actions) == 0:
                    cost = 1000
                else:
                    cost = len(sol.actions)
                    sol.to_file(problem + "/plan.%s" % str(i).zfill(2))

                duration = toc - tic

                print("Hypothesis %d: %d, %.2f" % (i, cost, duration))

                costs.append(cost)
                times.append(duration)

            with open(problem + "/costs", "w") as f:
                f.write(" ".join(map(str, costs)))

            with open(problem + "/times", "w") as f:
                f.write(" ".join(map(str, times)))

# %%
domain = "openstacks"
timeout = 120

# %%
# MONITORING

task = "monitoring"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/openstacks/monitoring/30/P00
# Correct hypothesis: 4
# Hypothesis 0: 20, 2.43
# Hypothesis 1: 20, 1.00
# Hypothesis 2: 1000, 0.89
# Hypothesis 3: 1000, 0.89
# Hypothesis 4: 20, 1.01
# Hypothesis 5: 20, 1.03
# benchmark/openstacks/monitoring/30/P01
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.34
# Hypothesis 1: 1000, 1.16
# Hypothesis 2: 21, 1.52
# Hypothesis 3: 1000, 1.11
# Hypothesis 4: 21, 1.51
# Hypothesis 5: 1000, 1.22
# benchmark/openstacks/monitoring/30/P02
# Correct hypothesis: 3
# Hypothesis 0: 18, 1.52
# Hypothesis 1: 1000, 1.17
# Hypothesis 2: 1000, 1.18
# Hypothesis 3: 18, 1.41
# Hypothesis 4: 18, 1.51
# benchmark/openstacks/monitoring/30/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 0.93
# Hypothesis 1: 18, 0.96
# Hypothesis 2: 20, 1.01
# Hypothesis 3: 22, 1.08
# Hypothesis 4: 18, 0.98
# Hypothesis 5: 1000, 0.91
# benchmark/openstacks/monitoring/30/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 0.91
# Hypothesis 1: 18, 0.96
# Hypothesis 2: 18, 0.96
# Hypothesis 3: 18, 0.96
# Hypothesis 4: 1000, 0.89
# Hypothesis 5: 1000, 0.89
# benchmark/openstacks/monitoring/30/P05
# Correct hypothesis: 4
# Hypothesis 0: 22, 1.11
# Hypothesis 1: 1000, 0.89
# Hypothesis 2: 20, 1.05
# Hypothesis 3: 1000, 0.93
# Hypothesis 4: 20, 1.06
# benchmark/openstacks/monitoring/30/P06
# Correct hypothesis: 4
# Hypothesis 0: 18, 1.02
# Hypothesis 1: 1000, 0.92
# Hypothesis 2: 1000, 0.94
# Hypothesis 3: 24, 1.30
# Hypothesis 4: 18, 0.97
# benchmark/openstacks/monitoring/30/P07
# Correct hypothesis: 3
# Hypothesis 0: 1000, 0.96
# Hypothesis 1: 1000, 0.97
# Hypothesis 2: 1000, 0.95
# Hypothesis 3: 26, 1.35
# Hypothesis 4: 1000, 0.98
# Hypothesis 5: 20, 1.10
# benchmark/openstacks/monitoring/30/P08
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.00
# Hypothesis 1: 20, 1.07
# Hypothesis 2: 26, 1.34
# Hypothesis 3: 1000, 0.97
# Hypothesis 4: 1000, 0.96
# benchmark/openstacks/monitoring/30/P09
# Correct hypothesis: 3
# Hypothesis 0: 20, 1.10
# Hypothesis 1: 1000, 0.88
# Hypothesis 2: 20, 1.00
# Hypothesis 3: 20, 1.00
# Hypothesis 4: 1000, 0.88
# Hypothesis 5: 1000, 0.89
# benchmark/openstacks/monitoring/50/P00
# Correct hypothesis: 4
# Hypothesis 0: 24, 1.29
# Hypothesis 1: 24, 1.26
# Hypothesis 2: 1000, 0.97
# Hypothesis 3: 1000, 0.96
# Hypothesis 4: 24, 1.26
# Hypothesis 5: 24, 1.26
# benchmark/openstacks/monitoring/50/P01
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.53
# Hypothesis 1: 1000, 1.31
# Hypothesis 2: 25, 1.75
# Hypothesis 3: 1000, 1.21
# Hypothesis 4: 25, 1.76
# Hypothesis 5: 1000, 1.41
# benchmark/openstacks/monitoring/50/P02
# Correct hypothesis: 3
# Hypothesis 0: 22, 1.78
# Hypothesis 1: 1000, 1.46
# Hypothesis 2: 1000, 1.47
# Hypothesis 3: 22, 1.64
# Hypothesis 4: 22, 1.74
# benchmark/openstacks/monitoring/50/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.03
# Hypothesis 1: 21, 1.10
# Hypothesis 2: 23, 1.18
# Hypothesis 3: 25, 1.30
# Hypothesis 4: 21, 1.11
# Hypothesis 5: 1000, 1.02
# benchmark/openstacks/monitoring/50/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 8.29
# Hypothesis 1: 20, 1.06
# Hypothesis 2: 20, 1.05
# Hypothesis 3: 20, 1.05
# Hypothesis 4: 1000, 0.95
# Hypothesis 5: 1000, 0.94
# benchmark/openstacks/monitoring/50/P05
# Correct hypothesis: 4
# Hypothesis 0: 26, 1.39
# Hypothesis 1: 1000, 1.09
# Hypothesis 2: 24, 1.32
# Hypothesis 3: 1000, 1.10
# Hypothesis 4: 24, 1.35
# benchmark/openstacks/monitoring/50/P06
# Correct hypothesis: 4
# Hypothesis 0: 21, 1.18
# Hypothesis 1: 1000, 1.00
# Hypothesis 2: 1000, 0.99
# Hypothesis 3: 27, 1.38
# Hypothesis 4: 21, 1.10
# benchmark/openstacks/monitoring/50/P07
# Correct hypothesis: 3
# Hypothesis 0: 1000, 1.03
# Hypothesis 1: 1000, 1.05
# Hypothesis 2: 1000, 1.02
# Hypothesis 3: 30, 1.50
# Hypothesis 4: 1000, 1.07
# Hypothesis 5: 25, 1.29
# benchmark/openstacks/monitoring/50/P08
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.12
# Hypothesis 1: 26, 1.31
# Hypothesis 2: 30, 1.49
# Hypothesis 3: 1000, 1.06
# Hypothesis 4: 1000, 1.08
# benchmark/openstacks/monitoring/50/P09
# Correct hypothesis: 3
# Hypothesis 0: 24, 1.27
# Hypothesis 1: 1000, 0.96
# Hypothesis 2: 24, 1.26
# Hypothesis 3: 24, 1.25
# Hypothesis 4: 1000, 0.97
# Hypothesis 5: 1000, 0.96
# benchmark/openstacks/monitoring/70/P00
# Correct hypothesis: 4
# Hypothesis 0: 27, 1.50
# Hypothesis 1: 27, 1.44
# Hypothesis 2: 1000, 1.03
# Hypothesis 3: 1000, 1.03
# Hypothesis 4: 27, 1.47
# Hypothesis 5: 27, 1.48
# benchmark/openstacks/monitoring/70/P01
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.64
# Hypothesis 1: 1000, 1.43
# Hypothesis 2: 28, 1.97
# Hypothesis 3: 1000, 1.32
# Hypothesis 4: 28, 11.28
# Hypothesis 5: 1000, 1.47
# benchmark/openstacks/monitoring/70/P02
# Correct hypothesis: 3
# Hypothesis 0: 25, 2.16
# Hypothesis 1: 1000, 1.61
# Hypothesis 2: 1000, 1.61
# Hypothesis 3: 25, 1.83
# Hypothesis 4: 25, 2.20
# benchmark/openstacks/monitoring/70/P03
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.02
# Hypothesis 1: 22, 1.17
# Hypothesis 2: 24, 1.25
# Hypothesis 3: 26, 1.38
# Hypothesis 4: 22, 1.19
# Hypothesis 5: 1000, 1.00
# benchmark/openstacks/monitoring/70/P04
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.02
# Hypothesis 1: 22, 1.16
# Hypothesis 2: 22, 1.15
# Hypothesis 3: 22, 1.17
# Hypothesis 4: 1000, 0.99
# Hypothesis 5: 1000, 0.99
# benchmark/openstacks/monitoring/70/P05
# Correct hypothesis: 4
# Hypothesis 0: 29, 1.55
# Hypothesis 1: 1000, 1.02
# Hypothesis 2: 27, 1.43
# Hypothesis 3: 1000, 1.05
# Hypothesis 4: 27, 12.68
# benchmark/openstacks/monitoring/70/P06
# Correct hypothesis: 4
# Hypothesis 0: 23, 1.40
# Hypothesis 1: 1000, 1.03
# Hypothesis 2: 1000, 1.04
# Hypothesis 3: 29, 1.42
# Hypothesis 4: 23, 1.23
# benchmark/openstacks/monitoring/70/P07
# Correct hypothesis: 3
# Hypothesis 0: 1000, 1.14
# Hypothesis 1: 1000, 1.14
# Hypothesis 2: 1000, 1.11
# Hypothesis 3: 34, 1.65
# Hypothesis 4: 1000, 1.18
# Hypothesis 5: 31, 1.51
# benchmark/openstacks/monitoring/70/P08
# Correct hypothesis: 2
# Hypothesis 0: 1000, 1.24
# Hypothesis 1: 31, 1.48
# Hypothesis 2: 35, 1.72
# Hypothesis 3: 1000, 1.22
# Hypothesis 4: 1000, 1.13
# benchmark/openstacks/monitoring/70/P09
# Correct hypothesis: 3
# Hypothesis 0: 28, 1.63
# Hypothesis 1: 1000, 1.02
# Hypothesis 2: 28, 1.44
# Hypothesis 3: 28, 1.47
# Hypothesis 4: 1000, 1.04
# Hypothesis 5: 1000, 1.04

# %%
# PREDICTION

task = "prediction"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/openstacks/prediction/30/P00
# Correct hypothesis: 3
# Hypothesis 0: 45, 2.10
# Hypothesis 1: 44, 9.27
# Hypothesis 2: 46, 9.24
# Hypothesis 3: 44, 1.99
# Hypothesis 4: 46, 2.70
# Hypothesis 5: 45, 9.33
# benchmark/openstacks/prediction/30/P01
# Correct hypothesis: 0
# Hypothesis 0: 42, 2.26
# Hypothesis 1: 43, 2.21
# Hypothesis 2: 42, 2.24
# Hypothesis 3: 43, 2.22
# Hypothesis 4: 43, 2.22
# Hypothesis 5: 42, 2.26
# benchmark/openstacks/prediction/30/P02
# Correct hypothesis: 1
# Hypothesis 0: 45, 3.17
# Hypothesis 1: 44, 2.75
# Hypothesis 2: 44, 2.71
# Hypothesis 3: 44, 2.73
# Hypothesis 4: 45, 2.70
# Hypothesis 5: 44, 2.72
# benchmark/openstacks/prediction/30/P03
# Correct hypothesis: 3
# Hypothesis 0: 46, 2.06
# Hypothesis 1: 45, 2.01
# Hypothesis 2: 46, 2.02
# Hypothesis 3: 44, 2.07
# Hypothesis 4: 45, 2.04
# Hypothesis 5: 46, 1.99
# benchmark/openstacks/prediction/30/P04
# Correct hypothesis: 3
# Hypothesis 0: 45, 2.06
# Hypothesis 1: 46, 1.96
# Hypothesis 2: 46, 2.35
# Hypothesis 3: 44, 2.02
# Hypothesis 4: 44, 2.03
# Hypothesis 5: 44, 2.04
# benchmark/openstacks/prediction/30/P05
# Correct hypothesis: 2
# Hypothesis 0: 44, 2.17
# Hypothesis 1: 46, 1.98
# Hypothesis 2: 44, 2.10
# Hypothesis 3: 44, 2.02
# Hypothesis 4: 44, 2.08
# Hypothesis 5: 45, 2.01
# benchmark/openstacks/prediction/30/P06
# Correct hypothesis: 0
# Hypothesis 0: 44, 2.10
# Hypothesis 1: 45, 2.03
# Hypothesis 2: 46, 2.08
# Hypothesis 3: 45, 2.15
# Hypothesis 4: 45, 2.18
# Hypothesis 5: 46, 2.10
# benchmark/openstacks/prediction/30/P07
# Correct hypothesis: 4
# Hypothesis 0: 47, 2.69
# Hypothesis 1: 45, 2.56
# Hypothesis 2: 46, 2.60
# Hypothesis 3: 47, 2.59
# Hypothesis 4: 45, 2.56
# benchmark/openstacks/prediction/30/P08
# Correct hypothesis: 1
# Hypothesis 0: 46, 2.79
# Hypothesis 1: 44, 2.53
# Hypothesis 2: 44, 13.78
# Hypothesis 3: 45, 9.96
# Hypothesis 4: 45, 2.60
# Hypothesis 5: 45, 2.61
# benchmark/openstacks/prediction/30/P09
# Correct hypothesis: 4
# Hypothesis 0: 47, 2.12
# Hypothesis 1: 46, 2.05
# Hypothesis 2: 47, 2.04
# Hypothesis 3: 45, 2.10
# Hypothesis 4: 45, 2.10
# Hypothesis 5: 45, 2.09
# benchmark/openstacks/prediction/50/P00
# Correct hypothesis: 3
# Hypothesis 0: 48, 2.33
# Hypothesis 1: 47, 2.26
# Hypothesis 2: 49, 2.19
# Hypothesis 3: 47, 2.24
# Hypothesis 4: 49, 2.20
# Hypothesis 5: 48, 2.23
# benchmark/openstacks/prediction/50/P01
# Correct hypothesis: 0
# Hypothesis 0: 46, 2.55
# Hypothesis 1: 47, 2.55
# Hypothesis 2: 46, 2.82
# Hypothesis 3: 47, 2.63
# Hypothesis 4: 47, 2.51
# Hypothesis 5: 46, 2.56
# benchmark/openstacks/prediction/50/P02
# Correct hypothesis: 1
# Hypothesis 0: 48, 3.03
# Hypothesis 1: 47, 2.88
# Hypothesis 2: 47, 3.42
# Hypothesis 3: 47, 3.37
# Hypothesis 4: 48, 3.30
# Hypothesis 5: 47, 10.38
# benchmark/openstacks/prediction/50/P03
# Correct hypothesis: 3
# Hypothesis 0: 49, 2.25
# Hypothesis 1: 48, 2.32
# Hypothesis 2: 49, 2.20
# Hypothesis 3: 47, 2.48
# Hypothesis 4: 48, 2.44
# Hypothesis 5: 49, 2.42
# benchmark/openstacks/prediction/50/P04
# Correct hypothesis: 3
# Hypothesis 0: 47, 3.15
# Hypothesis 1: 48, 2.93
# Hypothesis 2: 48, 2.86
# Hypothesis 3: 46, 2.66
# Hypothesis 4: 46, 2.64
# Hypothesis 5: 46, 2.74
# benchmark/openstacks/prediction/50/P05
# Correct hypothesis: 2
# Hypothesis 0: 46, 2.79
# Hypothesis 1: 48, 14.32
# Hypothesis 2: 46, 2.71
# Hypothesis 3: 46, 2.90
# Hypothesis 4: 46, 2.83
# Hypothesis 5: 47, 2.68
# benchmark/openstacks/prediction/50/P06
# Correct hypothesis: 0
# Hypothesis 0: 46, 2.75
# Hypothesis 1: 47, 2.85
# Hypothesis 2: 48, 2.72
# Hypothesis 3: 47, 2.88
# Hypothesis 4: 47, 2.92
# Hypothesis 5: 48, 2.75
# benchmark/openstacks/prediction/50/P07
# Correct hypothesis: 4
# Hypothesis 0: 50, 3.02
# Hypothesis 1: 48, 2.69
# Hypothesis 2: 49, 2.69
# Hypothesis 3: 50, 2.67
# Hypothesis 4: 48, 2.70
# benchmark/openstacks/prediction/50/P08
# Correct hypothesis: 1
# Hypothesis 0: 50, 2.79
# Hypothesis 1: 48, 2.66
# Hypothesis 2: 48, 2.71
# Hypothesis 3: 49, 2.72
# Hypothesis 4: 49, 2.69
# Hypothesis 5: 49, 9.87
# benchmark/openstacks/prediction/50/P09
# Correct hypothesis: 4
# Hypothesis 0: 49, 2.31
# Hypothesis 1: 48, 2.16
# Hypothesis 2: 49, 2.15
# Hypothesis 3: 47, 2.20
# Hypothesis 4: 47, 2.22
# Hypothesis 5: 47, 2.19
# benchmark/openstacks/prediction/70/P00
# Correct hypothesis: 3
# Hypothesis 0: 51, 2.44
# Hypothesis 1: 50, 2.60
# Hypothesis 2: 52, 2.34
# Hypothesis 3: 50, 2.34
# Hypothesis 4: 52, 2.33
# Hypothesis 5: 51, 2.36
# benchmark/openstacks/prediction/70/P01
# Correct hypothesis: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9fa15973c429> in <module>
#       2
#       3 task = "prediction"
# ----> 4 launch_experiments(domain, task, timeout)
#
# <ipython-input-2-70554fa7699e> in launch_experiments(domain, task, timeout)
#      34
#      35                 #Build a decoding problem for each hypothesis
# ---> 36                 T = DecodingTaskLTL(Mp,Ms,h)
#      37
#      38                 tic = time.time()
#
# ~/PhD/planning-inference/src/planning_inference/planning_inference.py in __init__(self, planning_model, sensor_model, hypothesis)
#      38         self.hypothesis = hypothesis
#      39
# ---> 40         self.compiled_model = self.__compile_model()
#      41         self.compiled_problem = self.__compile_problem()
#      42
#
# ~/PhD/planning-inference/src/planning_inference/planning_inference.py in __compile_model(self)
#      45         compiled_model.schemata = []
#      46
# ---> 47         dfa = self.hypothesis.get_dfa()
#      48
#      49         indices = sorted(list(dfa.nodes))
#
# ~/PhD/planning-inference/src/planning_inference/observations/trajectory.py in get_dfa(self)
#      59         parser = LTLfParser()
#      60         formula = parser(self.formula)
# ---> 61         dfa = formula.to_dfa()
#      62
#      63         G = nx.DiGraph()
#
# ~/python-venvs/planning_inference/lib/python3.6/site-packages/ltlf2dfa/ltlf.py in to_dfa(self)
#      51     def to_dfa(self) -> str:
#      52         """Translate into a DFA."""
# ---> 53         return to_dfa(self)
#      54
#      55
#
# ~/python-venvs/planning_inference/lib/python3.6/site-packages/ltlf2dfa/ltlf2dfa.py in to_dfa(f)
#     192     createMonafile(mona_p_string)
#     193     mona_dfa = invoke_mona()
# --> 194     return output2dot(mona_dfa)
#
# ~/python-venvs/planning_inference/lib/python3.6/site-packages/ltlf2dfa/ltlf2dfa.py in output2dot(mona_output)
#     180 def output2dot(mona_output):
#     181     """Parse the mona output or return the unsatisfiable dot."""
# --> 182     if "Formula is unsatisfiable" in mona_output:
#     183         return UNSAT_DOT
#     184     else:
#
# TypeError: argument of type 'bool' is not iterable

# %%
# HINDSIGHT

task = "hindsight"
launch_experiments(domain, task, timeout)
# Out:
# benchmark/openstacks/hindsight/30/P00
# Correct hypothesis: 4
# Hypothesis 0: 1000, 2.01
# Hypothesis 1: 1000, 1.92
# Hypothesis 2: 1000, 2.14
# Hypothesis 3: 1000, 1.23
# Hypothesis 4: 46, 2.32
# Hypothesis 5: 1000, 1.49
# benchmark/openstacks/hindsight/30/P01
# Correct hypothesis: 0
# Hypothesis 0: 36, 1.30
# Hypothesis 1: 1000, 1.49
# Hypothesis 2: 36, 1.34
# Hypothesis 3: 1000, 1.85
# Hypothesis 4: 1000, 1.51
# benchmark/openstacks/hindsight/30/P02
# Correct hypothesis: 0
# Hypothesis 0: 45, 2.51
# Hypothesis 1: 45, 2.75
# Hypothesis 2: 45, 2.49
# Hypothesis 3: 45, 2.52
# Hypothesis 4: 45, 2.57
# Hypothesis 5: 1000, 1.59
# benchmark/openstacks/hindsight/30/P03
# Correct hypothesis: 5
# Hypothesis 0: 45, 1.74
# Hypothesis 1: 45, 1.69
# Hypothesis 2: 1000, 1.83
# Hypothesis 3: 1000, 1.82
# Hypothesis 4: 1000, 1.96
# Hypothesis 5: 45, 1.71
# benchmark/openstacks/hindsight/30/P04
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.12
# Hypothesis 1: 1000, 1.37
# Hypothesis 2: 1000, 1.16
# Hypothesis 3: 1000, 1.10
# Hypothesis 4: 46, 1.65
# Hypothesis 5: 1000, 1.11
# benchmark/openstacks/hindsight/30/P05
# Correct hypothesis: 0
# Hypothesis 0: 41, 1.68
# Hypothesis 1: 1000, 1.00
# Hypothesis 2: 1000, 8.70
# Hypothesis 3: 41, 1.55
# Hypothesis 4: 1000, 1.38
# Hypothesis 5: 1000, 1.33
# benchmark/openstacks/hindsight/30/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 2.17
# Hypothesis 1: 44, 1.87
# Hypothesis 2: 1000, 1.51
# Hypothesis 3: 44, 1.74
# Hypothesis 4: 1000, 1.89
# benchmark/openstacks/hindsight/30/P07
# Correct hypothesis: 5
# Hypothesis 0: 1000, 2.55
# Hypothesis 1: 1000, 2.26
# Hypothesis 2: 1000, 3.12
# Hypothesis 3: 1000, 2.32
# Hypothesis 4: 1000, 3.09
# Hypothesis 5: 48, 2.47
# benchmark/openstacks/hindsight/30/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 1.62
# Hypothesis 1: 45, 1.76
# Hypothesis 2: 1000, 1.58
# Hypothesis 3: 1000, 1.66
# Hypothesis 4: 1000, 2.23
# Hypothesis 5: 1000, 2.40
# benchmark/openstacks/hindsight/30/P09
# Correct hypothesis: 0
# Hypothesis 0: 44, 1.66
# Hypothesis 1: 1000, 1.36
# Hypothesis 2: 1000, 1.17
# Hypothesis 3: 44, 1.65
# Hypothesis 4: 1000, 1.14
# Hypothesis 5: 1000, 1.76
# benchmark/openstacks/hindsight/50/P00
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.73
# Hypothesis 1: 1000, 1.47
# Hypothesis 2: 1000, 2.50
# Hypothesis 3: 1000, 1.52
# Hypothesis 4: 51, 1.80
# Hypothesis 5: 1000, 1.83
# benchmark/openstacks/hindsight/50/P01
# Correct hypothesis: 0
# Hypothesis 0: 43, 2.09
# Hypothesis 1: 1000, 1.89
# Hypothesis 2: 43, 1.75
# Hypothesis 3: 1000, 1.84
# Hypothesis 4: 1000, 1.89
# benchmark/openstacks/hindsight/50/P02
# Correct hypothesis: 0
# Hypothesis 0: 51, 2.56
# Hypothesis 1: 1000, 2.00
# Hypothesis 2: 51, 2.14
# Hypothesis 3: 1000, 1.76
# Hypothesis 4: 51, 2.11
# Hypothesis 5: 1000, 1.76
# benchmark/openstacks/hindsight/50/P03
# Correct hypothesis: 5
# Hypothesis 0: 52, 1.87
# Hypothesis 1: 52, 1.66
# Hypothesis 2: 1000, 2.26
# Hypothesis 3: 1000, 2.50
# Hypothesis 4: 1000, 2.42
# Hypothesis 5: 52, 1.68
# benchmark/openstacks/hindsight/50/P04
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.64
# Hypothesis 1: 1000, 1.85
# Hypothesis 2: 1000, 1.43
# Hypothesis 3: 1000, 1.42
# Hypothesis 4: 52, 1.79
# Hypothesis 5: 1000, 1.50
# benchmark/openstacks/hindsight/50/P05
# Correct hypothesis: 0
# Hypothesis 0: 48, 1.54
# Hypothesis 1: 1000, 1.38
# Hypothesis 2: 1000, 1.86
# Hypothesis 3: 48, 1.53
# Hypothesis 4: 1000, 1.67
# Hypothesis 5: 1000, 1.59
# benchmark/openstacks/hindsight/50/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 2.27
# Hypothesis 1: 1000, 1.64
# Hypothesis 2: 1000, 1.70
# Hypothesis 3: 51, 1.94
# Hypothesis 4: 1000, 2.04
# benchmark/openstacks/hindsight/50/P07
# Correct hypothesis: 5
# Hypothesis 0: 1000, 1.91
# Hypothesis 1: 1000, 1.91
# Hypothesis 2: 1000, 3.48
# Hypothesis 3: 1000, 1.82
# Hypothesis 4: 1000, 3.45
# Hypothesis 5: 54, 2.21
# benchmark/openstacks/hindsight/50/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 2.06
# Hypothesis 1: 51, 2.23
# Hypothesis 2: 1000, 1.82
# Hypothesis 3: 1000, 1.91
# Hypothesis 4: 1000, 1.49
# Hypothesis 5: 1000, 4.32
# benchmark/openstacks/hindsight/50/P09
# Correct hypothesis: 0
# Hypothesis 0: 51, 1.65
# Hypothesis 1: 1000, 1.95
# Hypothesis 2: 1000, 1.61
# Hypothesis 3: 51, 1.64
# Hypothesis 4: 1000, 1.61
# Hypothesis 5: 1000, 2.26
# benchmark/openstacks/hindsight/70/P00
# Correct hypothesis: 4
# Hypothesis 0: 1000, 1.96
# Hypothesis 1: 1000, 1.73
# Hypothesis 2: 1000, 4.25
# Hypothesis 3: 1000, 1.86
# Hypothesis 4: 57, 1.95
# Hypothesis 5: 1000, 2.04
# benchmark/openstacks/hindsight/70/P01
# Correct hypothesis: 0
# Hypothesis 0: 49, 2.22
# Hypothesis 1: 1000, 2.47
# Hypothesis 2: 49, 2.23
# Hypothesis 3: 1000, 2.57
# Hypothesis 4: 1000, 2.49
# benchmark/openstacks/hindsight/70/P02
# Correct hypothesis: 0
# Hypothesis 0: 56, 2.15
# Hypothesis 1: 1000, 2.58
# Hypothesis 2: 56, 1.98
# Hypothesis 3: 1000, 2.19
# Hypothesis 4: 56, 1.99
# Hypothesis 5: 1000, 2.20
# benchmark/openstacks/hindsight/70/P03
# Correct hypothesis: 5
# Hypothesis 0: 59, 1.89
# Hypothesis 1: 59, 1.75
# Hypothesis 2: 1000, 2.66
# Hypothesis 3: 1000, 2.64
# Hypothesis 4: 1000, 3.34
# Hypothesis 5: 59, 1.77
# benchmark/openstacks/hindsight/70/P04
# Correct hypothesis: 4
# Hypothesis 0: 1000, 2.19
# Hypothesis 1: 1000, 2.33
# Hypothesis 2: 1000, 1.80
# Hypothesis 3: 1000, 1.85
# Hypothesis 4: 58, 1.72
# Hypothesis 5: 1000, 2.03
# benchmark/openstacks/hindsight/70/P05
# Correct hypothesis: 0
# Hypothesis 0: 53, 1.93
# Hypothesis 1: 1000, 1.95
# Hypothesis 2: 1000, 2.31
# Hypothesis 3: 1000, 1.87
# Hypothesis 4: 1000, 1.95
# Hypothesis 5: 1000, 1.87
# benchmark/openstacks/hindsight/70/P06
# Correct hypothesis: 3
# Hypothesis 0: 1000, 2.98
# Hypothesis 1: 1000, 2.08
# Hypothesis 2: 1000, 2.13
# Hypothesis 3: 57, 1.87
# Hypothesis 4: 1000, 9.85
# benchmark/openstacks/hindsight/70/P07
# Correct hypothesis: 5
# Hypothesis 0: 1000, 2.44
# Hypothesis 1: 1000, 2.22
# Hypothesis 2: 1000, 2.00
# Hypothesis 3: 1000, 1.99
# Hypothesis 4: 1000, 6.04
# Hypothesis 5: 59, 2.46
# benchmark/openstacks/hindsight/70/P08
# Correct hypothesis: 1
# Hypothesis 0: 1000, 2.47
# Hypothesis 1: 58, 2.26
# Hypothesis 2: 1000, 2.89
# Hypothesis 3: 1000, 2.33
# Hypothesis 4: 1000, 1.82
# Hypothesis 5: 1000, 5.60
# benchmark/openstacks/hindsight/70/P09
# Correct hypothesis: 0
# Hypothesis 0: 58, 1.86
# Hypothesis 1: 1000, 2.39
# Hypothesis 2: 1000, 2.04
# Hypothesis 3: 58, 1.81
# Hypothesis 4: 1000, 1.95
# Hypothesis 5: 1000, 2.62
